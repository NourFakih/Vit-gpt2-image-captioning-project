# %% [markdown]
# ## Extract Frames From 100 Videos max for each category and Save them each in their corresponding video folder

# %%
import os
import cv2
import json
import re
import pandas as pd
from collections import defaultdict

# Paths for annotations, videos, output frames, and CSV file
ANNOTATIONS_FILE = '/kaggle/input/ucaucf-crime-annotation-dataset/UCFCrime_Test.json'
VIDEOS_DIR = '/kaggle/input/ucaucf-crime-annotation-dataset/UCF_Crimes/UCF_Crimes/Videos'    # e.g., "./UCF_Crimes/Videos/"
OUTPUT_DIR = 'output_frames'           # Folder to save the extracted frames
CSV_FILE = 'image_captions.csv'        # CSV file to save image path and caption pairs

# List of possible file extensions in your dataset
VIDEO_EXTENSIONS = ['.mp4', '.avi', '.mov', '.mkv']

# Maximum number of videos to process per category
MAX_PER_CATEGORY = 100

def find_video_file(video_name, base_dir, exts):
    """
    Search recursively under `base_dir` for a file that has the same
    (base) name as `video_name` and one of the allowed `exts`.
    Returns the full path if found, else None.
    """
    for root, dirs, files in os.walk(base_dir):
        for file in files:
            name, ext = os.path.splitext(file)
            if name == video_name and ext.lower() in exts:
                return os.path.join(root, file)
    return None

def extract_category_from_key(video_key):
    """
    Extract the category name from the start of the video key.
    For example, 'Abuse001_x264' -> 'Abuse'
    Adjust this logic if your naming convention is different.
    """
    match = re.match(r'([A-Za-z]+)', video_key)
    if match:
        return match.group(1)
    return "Unknown"

# Create the output directory if it doesn't exist
os.makedirs(OUTPUT_DIR, exist_ok=True)

# Load the JSON annotations
with open(ANNOTATIONS_FILE, 'r') as f:
    annotations = json.load(f)

# Keep track of how many videos processed per category
category_count = defaultdict(int)

# List to collect dictionaries with image paths and captions
data_entries = []

# Iterate over each video entry in the JSON
for video_name, data in annotations.items():
    # Identify the category from the video key
    category = extract_category_from_key(video_name)

    # If we already have 100 videos for this category, skip
    if category_count[category] >= MAX_PER_CATEGORY:
        continue

    # Attempt to find the actual video file in subfolders
    video_file = find_video_file(video_name, VIDEOS_DIR, VIDEO_EXTENSIONS)
    if not video_file:
        print(f"[WARNING] Could not find file for video key '{video_name}'")
        continue

    # Try to open the video
    cap = cv2.VideoCapture(video_file)
    if not cap.isOpened():
        print(f"[ERROR] Unable to open video file: {video_file}")
        continue

    fps = cap.get(cv2.CAP_PROP_FPS)
    print(f"Processing '{video_name}' in category '{category}' at {fps} fps.")

    # Create a subdirectory for frames from this video
    video_out_dir = os.path.join(OUTPUT_DIR, video_name)
    os.makedirs(video_out_dir, exist_ok=True)

    # Get timestamps and sentences lists
    timestamps = data.get("timestamps", [])
    sentences = data.get("sentences", [])

    frame_index = 0
    while True:
        ret, frame = cap.read()
        if not ret:
            break  # End of video

        # Sample every 20th frame (modify this value as needed)
        if frame_index % 20 == 0:
            current_time = frame_index / fps
            caption = None

            # Determine which timestamp interval covers the current frame time
            for idx, interval in enumerate(timestamps):
                start, end = interval
                if start <= current_time <= end:
                    caption = sentences[idx]
                    break

            # If a caption is found, save the frame and record the data
            if caption is not None:
                image_filename = f"{video_name}_frame{frame_index}.jpg"
                image_path = os.path.join(video_out_dir, image_filename)
                cv2.imwrite(image_path, frame)

                data_entries.append({
                    'image_path': image_path,
                    'caption': caption,
                    'video_key': video_name,
                    'category': category,
                    'frame_index': frame_index
                })
                #print(f"Saved: {image_path}, Caption: {caption}")

        frame_index += 1

    cap.release()

    # Increase the count for this category
    category_count[category] += 1

    # If we've now reached the max for this category, print a message
    if category_count[category] == MAX_PER_CATEGORY:
        print(f"[INFO] Reached {MAX_PER_CATEGORY} videos in category '{category}'.")

# Convert the collected data into a DataFrame and save as a CSV file
df = pd.DataFrame(data_entries)
df.to_csv(CSV_FILE, index=False)
print(f"Data saved to {CSV_FILE}")
# Out:
# Processing 'Abuse037_x264' in category 'Abuse' at 30.0 fps.
# Processing 'Abuse038_x264' in category 'Abuse' at 30.0 fps.
# Processing 'Abuse039_x264' in category 'Abuse' at 30.0 fps.
# Processing 'Abuse040_x264' in category 'Abuse' at 30.0 fps.
# Processing 'Abuse041_x264' in category 'Abuse' at 30.0 fps.
# Processing 'Abuse042_x264' in category 'Abuse' at 30.0 fps.
# Processing 'Arrest043_x264' in category 'Arrest' at 30.0 fps.
# Processing 'Arrest044_x264' in category 'Arrest' at 30.0 fps.
# Processing 'Arrest046_x264' in category 'Arrest' at 30.0 fps.
# Processing 'Arrest048_x264' in category 'Arrest' at 30.0 fps.
# Processing 'Arrest049_x264' in category 'Arrest' at 30.0 fps.
# Processing 'Arrest050_x264' in category 'Arrest' at 29.970029 fps.
# Processing 'Arrest051_x264' in category 'Arrest' at 30.0 fps.
# Processing 'Arson020_x264' in category 'Arson' at 30.0 fps.
# Processing 'Arson021_x264' in category 'Arson' at 30.0 fps.
# Processing 'Arson022_x264' in category 'Arson' at 30.0 fps.
# Processing 'Arson023_x264' in category 'Arson' at 30.0 fps.
# Processing 'Arson024_x264' in category 'Arson' at 30.0 fps.
# Processing 'Arson025_x264' in category 'Arson' at 30.0 fps.
# Processing 'Arson026_x264' in category 'Arson' at 30.0 fps.
# Processing 'Arson027_x264' in category 'Arson' at 30.0 fps.
# Processing 'Arson028_x264' in category 'Arson' at 30.0 fps.
# Processing 'Arson029_x264' in category 'Arson' at 30.0 fps.
# Processing 'Arson030_x264' in category 'Arson' at 30.0 fps.
# Processing 'Arson031_x264' in category 'Arson' at 30.0 fps.
# Processing 'Arson032_x264' in category 'Arson' at 30.0 fps.
# Processing 'Arson034_x264' in category 'Arson' at 30.0 fps.
# Processing 'Arson035_x264' in category 'Arson' at 30.0 fps.
# Processing 'Arson036_x264' in category 'Arson' at 30.0 fps.
# Processing 'Arson037_x264' in category 'Arson' at 30.0 fps.
# Processing 'Arson038_x264' in category 'Arson' at 30.0 fps.
# Processing 'Arson039_x264' in category 'Arson' at 30.0 fps.
# Processing 'Assault027_x264' in category 'Assault' at 30.0 fps.
# Processing 'Assault028_x264' in category 'Assault' at 30.0 fps.
# Processing 'Assault029_x264' in category 'Assault' at 30.0 fps.
# Processing 'Assault030_x264' in category 'Assault' at 30.0 fps.
# Processing 'Assault031_x264' in category 'Assault' at 30.0 fps.
# Processing 'Assault032_x264' in category 'Assault' at 30.0 fps.
# Processing 'Assault033_x264' in category 'Assault' at 30.0 fps.
# Processing 'Assault034_x264' in category 'Assault' at 30.0 fps.
# Processing 'Assault035_x264' in category 'Assault' at 30.0 fps.
# Processing 'Assault036_x264' in category 'Assault' at 30.0 fps.
# Processing 'Assault037_x264' in category 'Assault' at 30.0 fps.
# Processing 'Assault038_x264' in category 'Assault' at 30.0 fps.
# Processing 'Assault039_x264' in category 'Assault' at 30.0 fps.
# Processing 'Assault040_x264' in category 'Assault' at 30.0 fps.
# Processing 'Burglary065_x264' in category 'Burglary' at 30.0 fps.
# Processing 'Burglary066_x264' in category 'Burglary' at 30.0 fps.
# Processing 'Burglary067_x264' in category 'Burglary' at 30.0 fps.
# Processing 'Burglary068_x264' in category 'Burglary' at 30.0 fps.
# Processing 'Burglary069_x264' in category 'Burglary' at 30.0 fps.
# Processing 'Burglary070_x264' in category 'Burglary' at 30.0 fps.
# Processing 'Burglary071_x264' in category 'Burglary' at 30.0 fps.
# Processing 'Burglary072_x264' in category 'Burglary' at 30.0 fps.
# Processing 'Burglary073_x264' in category 'Burglary' at 30.0 fps.
# Processing 'Burglary074_x264' in category 'Burglary' at 30.0 fps.
# Processing 'Burglary075_x264' in category 'Burglary' at 30.0 fps.
# Processing 'Burglary076_x264' in category 'Burglary' at 30.0 fps.
# Processing 'Burglary077_x264' in category 'Burglary' at 30.0 fps.
# Processing 'Burglary078_x264' in category 'Burglary' at 30.0 fps.
# Processing 'Burglary079_x264' in category 'Burglary' at 30.0 fps.
# Processing 'Burglary080_x264' in category 'Burglary' at 30.0 fps.
# Processing 'Burglary081_x264' in category 'Burglary' at 30.0 fps.
# Processing 'Burglary082_x264' in category 'Burglary' at 30.0 fps.
# Processing 'Burglary083_x264' in category 'Burglary' at 30.0 fps.
# Processing 'Burglary084_x264' in category 'Burglary' at 30.0 fps.
# Processing 'Burglary085_x264' in category 'Burglary' at 30.0 fps.
# Processing 'Burglary086_x264' in category 'Burglary' at 30.0 fps.
# Processing 'Burglary087_x264' in category 'Burglary' at 30.0 fps.
# Processing 'Explosion007_x264' in category 'Explosion' at 30.0 fps.
# Processing 'Explosion008_x264' in category 'Explosion' at 30.0 fps.
# Processing 'Explosion009_x264' in category 'Explosion' at 30.0 fps.
# Processing 'Explosion010_x264' in category 'Explosion' at 30.0 fps.
# Processing 'Explosion011_x264' in category 'Explosion' at 30.0 fps.
# Processing 'Explosion012_x264' in category 'Explosion' at 30.0 fps.
# Processing 'Explosion013_x264' in category 'Explosion' at 30.0 fps.
# Processing 'Explosion014_x264' in category 'Explosion' at 30.0 fps.
# Processing 'Explosion015_x264' in category 'Explosion' at 30.0 fps.
# Processing 'Explosion016_x264' in category 'Explosion' at 30.0 fps.
# Processing 'Explosion017_x264' in category 'Explosion' at 30.0 fps.
# Processing 'Explosion018_x264' in category 'Explosion' at 30.0 fps.
# Processing 'Explosion019_x264' in category 'Explosion' at 30.0 fps.
# Processing 'Explosion020_x264' in category 'Explosion' at 30.0 fps.
# Processing 'Explosion021_x264' in category 'Explosion' at 30.0 fps.
# Processing 'Explosion022_x264' in category 'Explosion' at 30.0 fps.
# Processing 'Explosion023_x264' in category 'Explosion' at 30.0 fps.
# Processing 'Explosion024_x264' in category 'Explosion' at 30.0 fps.
# Processing 'Explosion025_x264' in category 'Explosion' at 30.0 fps.
# Processing 'Explosion026_x264' in category 'Explosion' at 30.0 fps.
# Processing 'Explosion027_x264' in category 'Explosion' at 30.0 fps.
# Processing 'Explosion028_x264' in category 'Explosion' at 30.0 fps.
# Processing 'Explosion029_x264' in category 'Explosion' at 30.0 fps.
# Processing 'Fighting039_x264' in category 'Fighting' at 30.0 fps.
# Processing 'Fighting040_x264' in category 'Fighting' at 30.0 fps.
# Processing 'Fighting041_x264' in category 'Fighting' at 30.0 fps.
# Processing 'Fighting042_x264' in category 'Fighting' at 30.0 fps.
# Processing 'Fighting043_x264' in category 'Fighting' at 30.0 fps.
# Processing 'Fighting044_x264' in category 'Fighting' at 30.0 fps.
# Processing 'RoadAccidents109_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents110_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents111_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents112_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents113_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents114_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents115_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents116_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents117_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents118_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents119_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents120_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents121_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents122_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents123_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents124_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents125_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents126_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents127_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents128_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents129_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents130_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents131_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents132_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents133_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents134_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents135_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents136_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents137_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents138_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents139_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents140_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents141_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents142_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents143_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'Robbery085_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery086_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery087_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery088_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery089_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery090_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery091_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery092_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery093_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery094_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery095_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery096_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery097_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery098_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery099_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery100_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery101_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery102_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery103_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery104_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery105_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery106_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery107_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery108_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery109_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery110_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery111_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery112_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Shooting033_x264' in category 'Shooting' at 30.0 fps.
# Processing 'Shooting034_x264' in category 'Shooting' at 30.0 fps.
# Processing 'Shooting036_x264' in category 'Shooting' at 30.0 fps.
# Processing 'Shooting037_x264' in category 'Shooting' at 30.0 fps.
# Processing 'Shooting038_x264' in category 'Shooting' at 30.0 fps.
# Processing 'Shooting039_x264' in category 'Shooting' at 30.0 fps.
# Processing 'Shooting040_x264' in category 'Shooting' at 30.0 fps.
# Processing 'Shooting041_x264' in category 'Shooting' at 30.0 fps.
# Processing 'Shooting042_x264' in category 'Shooting' at 30.0 fps.
# Processing 'Shooting043_x264' in category 'Shooting' at 30.0 fps.
# Processing 'Shooting044_x264' in category 'Shooting' at 30.0 fps.
# Processing 'Shooting046_x264' in category 'Shooting' at 30.0 fps.
# Processing 'Shoplifting034_x264' in category 'Shoplifting' at 30.0 fps.
# Processing 'Shoplifting036_x264' in category 'Shoplifting' at 30.0 fps.
# Processing 'Shoplifting037_x264' in category 'Shoplifting' at 30.0 fps.
# Processing 'Shoplifting038_x264' in category 'Shoplifting' at 30.0 fps.
# Processing 'Shoplifting039_x264' in category 'Shoplifting' at 30.0 fps.
# Processing 'Shoplifting040_x264' in category 'Shoplifting' at 30.0 fps.
# Processing 'Shoplifting041_x264' in category 'Shoplifting' at 30.0 fps.
# Processing 'Shoplifting042_x264' in category 'Shoplifting' at 30.0 fps.
# Processing 'Stealing078_x264' in category 'Stealing' at 30.0 fps.
# Processing 'Stealing079_x264' in category 'Stealing' at 30.0 fps.
# Processing 'Stealing080_x264' in category 'Stealing' at 30.0 fps.
# Processing 'Stealing081_x264' in category 'Stealing' at 30.0 fps.
# Processing 'Stealing082_x264' in category 'Stealing' at 30.0 fps.
# Processing 'Stealing083_x264' in category 'Stealing' at 30.0 fps.
# Processing 'Stealing084_x264' in category 'Stealing' at 30.0 fps.
# Processing 'Stealing086_x264' in category 'Stealing' at 30.0 fps.
# Processing 'Stealing087_x264' in category 'Stealing' at 30.0 fps.
# Processing 'Stealing088_x264' in category 'Stealing' at 30.0 fps.
# Processing 'Stealing089_x264' in category 'Stealing' at 30.0 fps.
# Processing 'Stealing091_x264' in category 'Stealing' at 30.0 fps.
# Processing 'Stealing092_x264' in category 'Stealing' at 30.0 fps.
# Processing 'Vandalism031_x264' in category 'Vandalism' at 30.0 fps.
# Processing 'Vandalism032_x264' in category 'Vandalism' at 30.0 fps.
# Processing 'Vandalism033_x264' in category 'Vandalism' at 30.0 fps.
# Processing 'Vandalism034_x264' in category 'Vandalism' at 30.0 fps.
# Processing 'Vandalism035_x264' in category 'Vandalism' at 30.0 fps.
# Processing 'Vandalism036_x264' in category 'Vandalism' at 30.0 fps.
# Processing 'Vandalism038_x264' in category 'Vandalism' at 30.0 fps.
# Processing 'Vandalism039_x264' in category 'Vandalism' at 30.0 fps.
# Processing 'Vandalism040_x264' in category 'Vandalism' at 30.0 fps.
# Processing 'Vandalism041_x264' in category 'Vandalism' at 30.0 fps.
# Processing 'Vandalism042_x264' in category 'Vandalism' at 30.0 fps.
# Processing 'Vandalism043_x264' in category 'Vandalism' at 30.0 fps.
# Processing 'Normal_Videos_924_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_925_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_926_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_928_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_929_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_930_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_931_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_932_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_933_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos534_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos535_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos536_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos537_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos538_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos539_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos540_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos541_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos542_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos544_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos545_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos546_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos547_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos548_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos549_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos550_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos551_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos552_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos553_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos554_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos555_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos556_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos557_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos558_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos559_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos560_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos561_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos562_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos563_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos564_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos565_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos566_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos567_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos568_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos569_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos570_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos571_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos572_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos573_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos574_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos575_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos577_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos578_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos579_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos580_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos581_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos582_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos583_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos584_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos585_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos586_x264' in category 'Normal' at 25.0 fps.
# Processing 'Normal_Videos587_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos588_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos589_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos590_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos591_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos592_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos593_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos594_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos598_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos599_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos600_x264' in category 'Normal' at 25.0 fps.
# Processing 'Normal_Videos601_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos602_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos604_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos605_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos608_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos609_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos610_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos611_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos612_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos613_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos614_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos615_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos616_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos617_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos618_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos619_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos620_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos622_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos623_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos624_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos625_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos626_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos627_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos628_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos629_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos630_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos631_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos632_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos633_x264' in category 'Normal' at 30.0 fps.
# [INFO] Reached 100 videos in category 'Normal'.
# Data saved to image_captions.csv

# %% [markdown]
# ## Extract Frames From 110 Videos max for each category

# %%
import os
import cv2
import json
import re
import pandas as pd
from collections import defaultdict

# Paths for annotations, videos, output frames, and CSV file
ANNOTATIONS_FILE = '/kaggle/input/ucaucf-crime-annotation-dataset/UCFCrime_Val.json'
VIDEOS_DIR = '/kaggle/input/ucaucf-crime-annotation-dataset/UCF_Crimes/UCF_Crimes/Videos'    # e.g., "./UCF_Crimes/Videos/"
OUTPUT_DIR = 'val_output_frames'           # All images will now be saved in one folder
CSV_FILE = 'Val_image_captions.csv'        # CSV file to save image path and caption pairs

# List of possible file extensions in your dataset
VIDEO_EXTENSIONS = ['.mp4', '.avi', '.mov', '.mkv']

# Maximum number of videos to process per category
MAX_PER_CATEGORY = 110

def find_video_file(video_name, base_dir, exts):
    """
    Search recursively under `base_dir` for a file that has the same
    (base) name as `video_name` and one of the allowed `exts`.
    Returns the full path if found, else None.
    """
    for root, dirs, files in os.walk(base_dir):
        for file in files:
            name, ext = os.path.splitext(file)
            if name == video_name and ext.lower() in exts:
                return os.path.join(root, file)
    return None

def extract_category_from_key(video_key):
    """
    Extract the category name from the start of the video key.
    For example, 'Abuse001_x264' -> 'Abuse'
    Adjust this logic if your naming convention is different.
    """
    match = re.match(r'([A-Za-z]+)', video_key)
    if match:
        return match.group(1)
    return "Unknown"

# Create the output directory if it doesn't exist
os.makedirs(OUTPUT_DIR, exist_ok=True)

# Load the JSON annotations
with open(ANNOTATIONS_FILE, 'r') as f:
    annotations = json.load(f)

# Keep track of how many videos processed per category
category_count = defaultdict(int)

# List to collect dictionaries with image paths and captions
data_entries = []

# Iterate over each video entry in the JSON
for video_name, data in annotations.items():
    # Identify the category from the video key
    category = extract_category_from_key(video_name)

    # If we already have 100 videos for this category, skip
    if category_count[category] >= MAX_PER_CATEGORY:
        continue

    # Attempt to find the actual video file in subfolders
    video_file = find_video_file(video_name, VIDEOS_DIR, VIDEO_EXTENSIONS)
    if not video_file:
        print(f"[WARNING] Could not find file for video key '{video_name}'")
        continue

    # Try to open the video
    cap = cv2.VideoCapture(video_file)
    if not cap.isOpened():
        print(f"[ERROR] Unable to open video file: {video_file}")
        continue

    fps = cap.get(cv2.CAP_PROP_FPS)
    print(f"Processing '{video_name}' in category '{category}' at {fps} fps.")

    # Get timestamps and sentences lists
    timestamps = data.get("timestamps", [])
    sentences = data.get("sentences", [])

    frame_index = 0
    while True:
        ret, frame = cap.read()
        if not ret:
            break  # End of video

        # Sample every 20th frame (modify this value as needed)
        if frame_index % 20 == 0:
            current_time = frame_index / fps
            caption = None

            # Determine which timestamp interval covers the current frame time
            for idx, interval in enumerate(timestamps):
                start, end = interval
                if start <= current_time <= end:
                    caption = sentences[idx]
                    break

            # If a caption is found, save the frame and record the data
            if caption is not None:
                image_filename = f"{video_name}_frame{frame_index}.jpg"
                image_path = os.path.join(OUTPUT_DIR, image_filename)
                cv2.imwrite(image_path, frame)

                data_entries.append({
                    'image_path': image_path,
                    'caption': caption,
                    'video_key': video_name,
                    'category': category,
                    'frame_index': frame_index
                })
                #print(f"Saved: {image_path}, Caption: {caption}")

        frame_index += 1

    cap.release()

    # Increase the count for this category
    category_count[category] += 1

    # If we've now reached the max for this category, print a message
    if category_count[category] == MAX_PER_CATEGORY:
        print(f"[INFO] Reached {MAX_PER_CATEGORY} videos in category '{category}'.")
# Out:
# Processing 'Abuse043_x264' in category 'Abuse' at 30.0 fps.
# Processing 'Abuse044_x264' in category 'Abuse' at 30.0 fps.
# Processing 'Abuse045_x264' in category 'Abuse' at 30.0 fps.
# Processing 'Abuse046_x264' in category 'Abuse' at 30.0 fps.
# Processing 'Abuse047_x264' in category 'Abuse' at 30.0 fps.
# Processing 'Abuse048_x264' in category 'Abuse' at 30.0 fps.
# Processing 'Abuse049_x264' in category 'Abuse' at 30.0 fps.
# Processing 'Abuse050_x264' in category 'Abuse' at 30.0 fps.
# Processing 'Arrest047_x264' in category 'Arrest' at 30.0 fps.
# Processing 'Arson040_x264' in category 'Arson' at 30.0 fps.
# Processing 'Arson041_x264' in category 'Arson' at 30.0 fps.
# Processing 'Arson042_x264' in category 'Arson' at 30.0 fps.
# Processing 'Arson044_x264' in category 'Arson' at 30.0 fps.
# Processing 'Arson045_x264' in category 'Arson' at 30.0 fps.
# Processing 'Arson046_x264' in category 'Arson' at 30.0 fps.
# Processing 'Arson047_x264' in category 'Arson' at 30.0 fps.
# Processing 'Arson048_x264' in category 'Arson' at 30.0 fps.
# Processing 'Arson049_x264' in category 'Arson' at 30.0 fps.
# Processing 'Arson050_x264' in category 'Arson' at 30.0 fps.
# Processing 'Arson051_x264' in category 'Arson' at 30.0 fps.
# Processing 'Arson052_x264' in category 'Arson' at 30.0 fps.
# Processing 'Arson053_x264' in category 'Arson' at 30.0 fps.
# Processing 'Assault041_x264' in category 'Assault' at 30.0 fps.
# Processing 'Assault042_x264' in category 'Assault' at 30.0 fps.
# Processing 'Assault044_x264' in category 'Assault' at 30.0 fps.
# Processing 'Assault047_x264' in category 'Assault' at 30.0 fps.
# Processing 'Assault048_x264' in category 'Assault' at 30.0 fps.
# Processing 'Assault049_x264' in category 'Assault' at 30.0 fps.
# Processing 'Assault050_x264' in category 'Assault' at 30.0 fps.
# Processing 'Assault051_x264' in category 'Assault' at 30.0 fps.
# Processing 'Assault052_x264' in category 'Assault' at 30.0 fps.
# Processing 'Burglary088_x264' in category 'Burglary' at 30.0 fps.
# Processing 'Burglary089_x264' in category 'Burglary' at 30.0 fps.
# Processing 'Burglary090_x264' in category 'Burglary' at 30.0 fps.
# Processing 'Burglary091_x264' in category 'Burglary' at 30.0 fps.
# Processing 'Burglary092_x264' in category 'Burglary' at 30.0 fps.
# Processing 'Burglary093_x264' in category 'Burglary' at 30.0 fps.
# Processing 'Burglary094_x264' in category 'Burglary' at 30.0 fps.
# Processing 'Burglary095_x264' in category 'Burglary' at 30.0 fps.
# Processing 'Burglary096_x264' in category 'Burglary' at 30.0 fps.
# Processing 'Burglary097_x264' in category 'Burglary' at 30.0 fps.
# Processing 'Burglary098_x264' in category 'Burglary' at 30.0 fps.
# Processing 'Burglary099_x264' in category 'Burglary' at 30.0 fps.
# Processing 'Burglary100_x264' in category 'Burglary' at 30.0 fps.
# Processing 'Explosion030_x264' in category 'Explosion' at 30.0 fps.
# Processing 'Explosion032_x264' in category 'Explosion' at 30.0 fps.
# Processing 'Explosion033_x264' in category 'Explosion' at 30.0 fps.
# Processing 'Explosion034_x264' in category 'Explosion' at 30.0 fps.
# Processing 'Explosion035_x264' in category 'Explosion' at 30.0 fps.
# Processing 'Explosion036_x264' in category 'Explosion' at 30.0 fps.
# Processing 'Explosion037_x264' in category 'Explosion' at 30.0 fps.
# Processing 'Explosion038_x264' in category 'Explosion' at 30.0 fps.
# Processing 'Explosion039_x264' in category 'Explosion' at 30.0 fps.
# Processing 'Explosion040_x264' in category 'Explosion' at 30.0 fps.
# Processing 'Explosion041_x264' in category 'Explosion' at 30.0 fps.
# Processing 'Explosion042_x264' in category 'Explosion' at 30.0 fps.
# Processing 'Explosion043_x264' in category 'Explosion' at 30.0 fps.
# Processing 'Explosion044_x264' in category 'Explosion' at 30.0 fps.
# Processing 'Explosion045_x264' in category 'Explosion' at 30.0 fps.
# Processing 'Explosion047_x264' in category 'Explosion' at 30.0 fps.
# Processing 'Explosion048_x264' in category 'Explosion' at 30.0 fps.
# Processing 'Explosion050_x264' in category 'Explosion' at 30.0 fps.
# Processing 'Explosion051_x264' in category 'Explosion' at 30.0 fps.
# Processing 'Explosion052_x264' in category 'Explosion' at 30.0 fps.
# Processing 'Fighting045_x264' in category 'Fighting' at 30.0 fps.
# Processing 'Fighting046_x264' in category 'Fighting' at 30.0 fps.
# Processing 'Fighting047_x264' in category 'Fighting' at 30.0 fps.
# Processing 'Fighting048_x264' in category 'Fighting' at 30.0 fps.
# Processing 'Fighting049_x264' in category 'Fighting' at 30.0 fps.
# Processing 'Fighting050_x264' in category 'Fighting' at 30.0 fps.
# Processing 'Fighting051_x264' in category 'Fighting' at 30.0 fps.
# Processing 'RoadAccidents145_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents146_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents147_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents148_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents149_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents150_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents151_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'Robbery113_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery114_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery115_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery116_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery117_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery118_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery119_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery120_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery121_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery122_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery123_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery124_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery125_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery126_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery127_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery128_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery129_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery130_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery131_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery132_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery133_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery134_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery135_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery136_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery137_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery138_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery140_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery141_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery142_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery143_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery144_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery145_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery146_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery147_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery148_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery149_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery150_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Shooting047_x264' in category 'Shooting' at 30.0 fps.
# Processing 'Shooting048_x264' in category 'Shooting' at 30.0 fps.
# Processing 'Shooting050_x264' in category 'Shooting' at 30.0 fps.
# Processing 'Shooting051_x264' in category 'Shooting' at 30.0 fps.
# Processing 'Shooting052_x264' in category 'Shooting' at 30.0 fps.
# Processing 'Shooting053_x264' in category 'Shooting' at 30.0 fps.
# Processing 'Shooting054_x264' in category 'Shooting' at 30.0 fps.
# Processing 'Shoplifting043_x264' in category 'Shoplifting' at 30.0 fps.
# Processing 'Shoplifting044_x264' in category 'Shoplifting' at 30.0 fps.
# Processing 'Shoplifting045_x264' in category 'Shoplifting' at 30.0 fps.
# Processing 'Shoplifting047_x264' in category 'Shoplifting' at 30.0 fps.
# Processing 'Shoplifting048_x264' in category 'Shoplifting' at 30.0 fps.
# Processing 'Shoplifting049_x264' in category 'Shoplifting' at 30.0 fps.
# Processing 'Shoplifting050_x264' in category 'Shoplifting' at 30.0 fps.
# Processing 'Shoplifting051_x264' in category 'Shoplifting' at 30.0 fps.
# Processing 'Shoplifting052_x264' in category 'Shoplifting' at 30.0 fps.
# Processing 'Shoplifting053_x264' in category 'Shoplifting' at 30.0 fps.
# Processing 'Shoplifting054_x264' in category 'Shoplifting' at 30.0 fps.
# Processing 'Shoplifting055_x264' in category 'Shoplifting' at 30.0 fps.
# Processing 'Stealing093_x264' in category 'Stealing' at 30.0 fps.
# Processing 'Stealing094_x264' in category 'Stealing' at 30.0 fps.
# Processing 'Stealing095_x264' in category 'Stealing' at 30.0 fps.
# Processing 'Stealing096_x264' in category 'Stealing' at 30.0 fps.
# Processing 'Stealing097_x264' in category 'Stealing' at 30.0 fps.
# Processing 'Stealing098_x264' in category 'Stealing' at 30.0 fps.
# Processing 'Stealing100_x264' in category 'Stealing' at 30.0 fps.
# Processing 'Stealing101_x264' in category 'Stealing' at 30.0 fps.
# Processing 'Stealing102_x264' in category 'Stealing' at 30.0 fps.
# Processing 'Stealing103_x264' in category 'Stealing' at 30.0 fps.
# Processing 'Stealing104_x264' in category 'Stealing' at 30.0 fps.
# Processing 'Stealing105_x264' in category 'Stealing' at 30.0 fps.
# Processing 'Stealing106_x264' in category 'Stealing' at 30.0 fps.
# Processing 'Stealing107_x264' in category 'Stealing' at 30.0 fps.
# Processing 'Stealing108_x264' in category 'Stealing' at 30.0 fps.
# Processing 'Stealing109_x264' in category 'Stealing' at 30.0 fps.
# Processing 'Stealing110_x264' in category 'Stealing' at 30.0 fps.
# Processing 'Stealing111_x264' in category 'Stealing' at 30.0 fps.
# Processing 'Stealing112_x264' in category 'Stealing' at 30.0 fps.
# Processing 'Stealing113_x264' in category 'Stealing' at 30.0 fps.
# Processing 'Stealing114_x264' in category 'Stealing' at 30.0 fps.
# Processing 'Vandalism044_x264' in category 'Vandalism' at 30.0 fps.
# Processing 'Vandalism045_x264' in category 'Vandalism' at 30.0 fps.
# Processing 'Vandalism046_x264' in category 'Vandalism' at 30.0 fps.
# Processing 'Vandalism047_x264' in category 'Vandalism' at 30.0 fps.
# Processing 'Vandalism048_x264' in category 'Vandalism' at 30.0 fps.
# Processing 'Vandalism049_x264' in category 'Vandalism' at 30.0 fps.
# Processing 'Vandalism050_x264' in category 'Vandalism' at 30.0 fps.
# Processing 'Normal_Videos_934_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_935_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_936_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_938_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_939_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_940_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_941_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_943_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_944_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos639_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos640_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos643_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos644_x264' in category 'Normal' at 25.0 fps.
# Processing 'Normal_Videos645_x264' in category 'Normal' at 25.0 fps.
# Processing 'Normal_Videos646_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos647_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos648_x264' in category 'Normal' at 25.0 fps.
# Processing 'Normal_Videos649_x264' in category 'Normal' at 25.0 fps.
# Processing 'Normal_Videos650_x264' in category 'Normal' at 25.0 fps.
# Processing 'Normal_Videos651_x264' in category 'Normal' at 25.0 fps.
# Processing 'Normal_Videos652_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos653_x264' in category 'Normal' at 25.0 fps.
# Processing 'Normal_Videos654_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos655_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos657_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos658_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos659_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos660_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos661_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos662_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos663_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos664_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos665_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos667_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos668_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos669_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos670_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos671_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos672_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos673_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos674_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos675_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos676_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos677_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos678_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos679_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos680_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos681_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos682_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos683_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos684_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos685_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos687_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos689_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos691_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos692_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos693_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos694_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos695_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos697_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos698_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos699_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos700_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos701_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos703_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos705_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos706_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos707_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos708_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos709_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos711_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos712_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos713_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos714_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos715_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos718_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos719_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos720_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos721_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos723_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos724_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos726_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos727_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos728_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos729_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos730_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos731_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos732_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos733_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos734_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos735_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos736_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos737_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos738_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos739_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos740_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos741_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos742_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos743_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos744_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos746_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos747_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos748_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos749_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos750_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos751_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos752_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos753_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos754_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos756_x264' in category 'Normal' at 30.0 fps.
# [INFO] Reached 110 videos in category 'Normal'.

# %% [markdown]
# ## Process with PySceneDetect to get key frames

# %%
import os
import cv2
import json
import re
import pandas as pd
from collections import defaultdict

# 1) Import PySceneDetect
# !pip install scenedetect --quiet
from scenedetect import VideoManager, SceneManager
from scenedetect.detectors import ContentDetector
from scenedetect.scene_manager import StatsManager

# Paths for annotations, videos, output frames, and CSV file
ANNOTATIONS_FILE = '/kaggle/input/ucaucf-crime-annotation-dataset/UCFCrime_Val.json'
VIDEOS_DIR = '/kaggle/input/ucaucf-crime-annotation-dataset/UCF_Crimes/UCF_Crimes/Videos'  # Adjust if needed
OUTPUT_DIR = 'val_output_frames'          # All images saved in one folder
CSV_FILE = 'Val_image_captions.csv'       # CSV file to save image path & caption pairs

# List of possible file extensions in your dataset
VIDEO_EXTENSIONS = ['.mp4', '.avi', '.mov', '.mkv']

# Max number of videos to process per category
MAX_PER_CATEGORY = 110

def find_video_file(video_name, base_dir, exts):
    """
    Search recursively under `base_dir` for a file that has the same
    (base) name as `video_name` and one of the allowed `exts`.
    Returns the full path if found, else None.
    """
    for root, dirs, files in os.walk(base_dir):
        for file in files:
            name, ext = os.path.splitext(file)
            if name == video_name and ext.lower() in exts:
                return os.path.join(root, file)
    return None

def extract_category_from_key(video_key):
    """
    Extract the category name from the start of the video key.
    E.g., 'Abuse001_x264' -> 'Abuse'.
    Adjust logic if your naming convention differs.
    """
    match = re.match(r'([A-Za-z]+)', video_key)
    if match:
        return match.group(1)
    return "Unknown"

# Create the output directory if it doesn't exist
os.makedirs(OUTPUT_DIR, exist_ok=True)

# Load the JSON annotations
with open(ANNOTATIONS_FILE, 'r') as f:
    annotations = json.load(f)

# Track how many videos processed per category
category_count = defaultdict(int)

# List to collect dictionaries with image paths and captions
data_entries = []

# 2) Function to detect scenes and pick key frames
def detect_scenes_and_extract_frames(video_path, video_name, category, timestamps, sentences):
    """
    Use PySceneDetect to detect scene boundaries and then extract a representative frame
    from each scene. For each key frame, find which caption it belongs to (using timestamps).
    """
    # --- Setup PySceneDetect ---
    video_manager = VideoManager([video_path])
    stats_manager = StatsManager()
    scene_manager = SceneManager(stats_manager)
    
    # ContentDetector: you can tune the threshold to get more/fewer scenes
    scene_manager.add_detector(ContentDetector(threshold=30.0))
    
    # Start the video manager & perform scene detection
    video_manager.start()
    scene_manager.detect_scenes(frame_source=video_manager)
    scene_list = scene_manager.get_scene_list()
    
    # Re-open video with OpenCV for frame extraction
    cap = cv2.VideoCapture(video_path)
    fps = cap.get(cv2.CAP_PROP_FPS)
    
    frames_and_captions = []  # store (frame_index, caption) pairs

    # 3) For each scene, pick a representative frame
    for i, scene in enumerate(scene_list):
        start_tc, end_tc = scene
        start_frame = start_tc.get_frames()
        end_frame = end_tc.get_frames()
        
        # Pick the midpoint frame of the scene
        mid_frame = (start_frame + end_frame) // 2
        cap.set(cv2.CAP_PROP_POS_FRAMES, mid_frame)
        ret, frame = cap.read()
        if not ret:
            continue
        
        # Find the time (in seconds) for the mid frame
        mid_time_sec = mid_frame / fps
        
        # Match to the correct caption based on timestamps
        matched_caption = None
        for idx, interval in enumerate(timestamps):
            start, end = interval
            if start <= mid_time_sec <= end:
                matched_caption = sentences[idx]
                break
        
        if matched_caption:
            image_filename = f"{video_name}_frame{mid_frame}.jpg"
            image_path = os.path.join(OUTPUT_DIR, image_filename)
            cv2.imwrite(image_path, frame)
            
            frames_and_captions.append({
                'image_path': image_path,
                'caption': matched_caption,
                'video_key': video_name,
                'category': category,
                'frame_index': mid_frame
            })
    
    cap.release()
    video_manager.release()
    return frames_and_captions

# 4) Main loop: process each video using scene detection
for video_name, data in annotations.items():
    # Identify the category from the video key
    category = extract_category_from_key(video_name)

    # If we already have enough videos for this category, skip
    if category_count[category] >= MAX_PER_CATEGORY:
        continue

    # Find the actual video file
    video_file = find_video_file(video_name, VIDEOS_DIR, VIDEO_EXTENSIONS)
    if not video_file:
        print(f"[WARNING] Could not find file for video key '{video_name}'")
        continue

    # Extract timestamps and sentences
    timestamps = data.get("timestamps", [])  # list of (start, end) in seconds
    sentences = data.get("sentences", [])    # list of caption strings

    print(f"Processing '{video_name}' in category '{category}'...")

    # Use PySceneDetect to get key frames
    frames_captions = detect_scenes_and_extract_frames(
        video_path=video_file,
        video_name=video_name,
        category=category,
        timestamps=timestamps,
        sentences=sentences
    )

    # Append results
    data_entries.extend(frames_captions)

    # Increase the count for this category
    category_count[category] += 1
    if category_count[category] == MAX_PER_CATEGORY:
        print(f"[INFO] Reached {MAX_PER_CATEGORY} videos in category '{category}'.")

# 5) Convert to DataFrame and save to CSV
df = pd.DataFrame(data_entries)
df.to_csv(CSV_FILE, index=False)
print(f"\n[INFO] Saved {len(df)} extracted frames to '{CSV_FILE}'.")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.6/131.6 kB 3.2 MB/s eta 0:00:00
# Processing 'Abuse043_x264' in category 'Abuse'...
# Processing 'Abuse044_x264' in category 'Abuse'...
# Processing 'Abuse045_x264' in category 'Abuse'...
# Processing 'Abuse046_x264' in category 'Abuse'...
# Processing 'Abuse047_x264' in category 'Abuse'...
# Processing 'Abuse048_x264' in category 'Abuse'...
# Processing 'Abuse049_x264' in category 'Abuse'...
# Processing 'Abuse050_x264' in category 'Abuse'...
# Processing 'Arrest047_x264' in category 'Arrest'...
# Processing 'Arson040_x264' in category 'Arson'...
# Processing 'Arson041_x264' in category 'Arson'...
# Processing 'Arson042_x264' in category 'Arson'...
# Processing 'Arson044_x264' in category 'Arson'...
# Processing 'Arson045_x264' in category 'Arson'...
# Processing 'Arson046_x264' in category 'Arson'...
# Processing 'Arson047_x264' in category 'Arson'...
# Processing 'Arson048_x264' in category 'Arson'...
# Processing 'Arson049_x264' in category 'Arson'...
# Processing 'Arson050_x264' in category 'Arson'...
# Processing 'Arson051_x264' in category 'Arson'...
# Processing 'Arson052_x264' in category 'Arson'...
# Processing 'Arson053_x264' in category 'Arson'...
# Processing 'Assault041_x264' in category 'Assault'...
# Processing 'Assault042_x264' in category 'Assault'...
# Processing 'Assault044_x264' in category 'Assault'...
# Processing 'Assault047_x264' in category 'Assault'...
# Processing 'Assault048_x264' in category 'Assault'...
# Processing 'Assault049_x264' in category 'Assault'...
# Processing 'Assault050_x264' in category 'Assault'...
# Processing 'Assault051_x264' in category 'Assault'...
# Processing 'Assault052_x264' in category 'Assault'...
# Processing 'Burglary088_x264' in category 'Burglary'...
# Processing 'Burglary089_x264' in category 'Burglary'...
# Processing 'Burglary090_x264' in category 'Burglary'...
# Processing 'Burglary091_x264' in category 'Burglary'...
# Processing 'Burglary092_x264' in category 'Burglary'...
# Processing 'Burglary093_x264' in category 'Burglary'...
# Processing 'Burglary094_x264' in category 'Burglary'...
# Processing 'Burglary095_x264' in category 'Burglary'...
# Processing 'Burglary096_x264' in category 'Burglary'...
# Processing 'Burglary097_x264' in category 'Burglary'...
# Processing 'Burglary098_x264' in category 'Burglary'...
# Processing 'Burglary099_x264' in category 'Burglary'...
# Processing 'Burglary100_x264' in category 'Burglary'...
# Processing 'Explosion030_x264' in category 'Explosion'...
# Processing 'Explosion032_x264' in category 'Explosion'...
# Processing 'Explosion033_x264' in category 'Explosion'...
# Processing 'Explosion034_x264' in category 'Explosion'...
# Processing 'Explosion035_x264' in category 'Explosion'...
# Processing 'Explosion036_x264' in category 'Explosion'...
# Processing 'Explosion037_x264' in category 'Explosion'...
# Processing 'Explosion038_x264' in category 'Explosion'...
# Processing 'Explosion039_x264' in category 'Explosion'...
# Processing 'Explosion040_x264' in category 'Explosion'...
# Processing 'Explosion041_x264' in category 'Explosion'...
# Processing 'Explosion042_x264' in category 'Explosion'...
# Processing 'Explosion043_x264' in category 'Explosion'...
# Processing 'Explosion044_x264' in category 'Explosion'...
# Processing 'Explosion045_x264' in category 'Explosion'...
# Processing 'Explosion047_x264' in category 'Explosion'...
# Processing 'Explosion048_x264' in category 'Explosion'...
# Processing 'Explosion050_x264' in category 'Explosion'...
# Processing 'Explosion051_x264' in category 'Explosion'...
# Processing 'Explosion052_x264' in category 'Explosion'...
# Processing 'Fighting045_x264' in category 'Fighting'...
# Processing 'Fighting046_x264' in category 'Fighting'...
# Processing 'Fighting047_x264' in category 'Fighting'...
# Processing 'Fighting048_x264' in category 'Fighting'...
# Processing 'Fighting049_x264' in category 'Fighting'...
# Processing 'Fighting050_x264' in category 'Fighting'...
# Processing 'Fighting051_x264' in category 'Fighting'...
# Processing 'RoadAccidents145_x264' in category 'RoadAccidents'...
# Processing 'RoadAccidents146_x264' in category 'RoadAccidents'...
# Processing 'RoadAccidents147_x264' in category 'RoadAccidents'...
# Processing 'RoadAccidents148_x264' in category 'RoadAccidents'...
# Processing 'RoadAccidents149_x264' in category 'RoadAccidents'...
# Processing 'RoadAccidents150_x264' in category 'RoadAccidents'...
# Processing 'RoadAccidents151_x264' in category 'RoadAccidents'...
# Processing 'Robbery113_x264' in category 'Robbery'...
# Processing 'Robbery114_x264' in category 'Robbery'...
# Processing 'Robbery115_x264' in category 'Robbery'...
# Processing 'Robbery116_x264' in category 'Robbery'...
# Processing 'Robbery117_x264' in category 'Robbery'...
# Processing 'Robbery118_x264' in category 'Robbery'...
# Processing 'Robbery119_x264' in category 'Robbery'...
# Processing 'Robbery120_x264' in category 'Robbery'...
# Processing 'Robbery121_x264' in category 'Robbery'...
# Processing 'Robbery122_x264' in category 'Robbery'...
# Processing 'Robbery123_x264' in category 'Robbery'...
# Processing 'Robbery124_x264' in category 'Robbery'...
# Processing 'Robbery125_x264' in category 'Robbery'...
# Processing 'Robbery126_x264' in category 'Robbery'...
# Processing 'Robbery127_x264' in category 'Robbery'...
# Processing 'Robbery128_x264' in category 'Robbery'...
# Processing 'Robbery129_x264' in category 'Robbery'...
# Processing 'Robbery130_x264' in category 'Robbery'...
# Processing 'Robbery131_x264' in category 'Robbery'...
# Processing 'Robbery132_x264' in category 'Robbery'...
# Processing 'Robbery133_x264' in category 'Robbery'...
# Processing 'Robbery134_x264' in category 'Robbery'...
# Processing 'Robbery135_x264' in category 'Robbery'...
# Processing 'Robbery136_x264' in category 'Robbery'...
# Processing 'Robbery137_x264' in category 'Robbery'...
# Processing 'Robbery138_x264' in category 'Robbery'...
# Processing 'Robbery140_x264' in category 'Robbery'...
# Processing 'Robbery141_x264' in category 'Robbery'...
# Processing 'Robbery142_x264' in category 'Robbery'...
# Processing 'Robbery143_x264' in category 'Robbery'...
# Processing 'Robbery144_x264' in category 'Robbery'...
# Processing 'Robbery145_x264' in category 'Robbery'...
# Processing 'Robbery146_x264' in category 'Robbery'...
# Processing 'Robbery147_x264' in category 'Robbery'...
# Processing 'Robbery148_x264' in category 'Robbery'...
# Processing 'Robbery149_x264' in category 'Robbery'...
# Processing 'Robbery150_x264' in category 'Robbery'...
# Processing 'Shooting047_x264' in category 'Shooting'...
# Processing 'Shooting048_x264' in category 'Shooting'...
# Processing 'Shooting050_x264' in category 'Shooting'...
# Processing 'Shooting051_x264' in category 'Shooting'...
# Processing 'Shooting052_x264' in category 'Shooting'...
# Processing 'Shooting053_x264' in category 'Shooting'...
# Processing 'Shooting054_x264' in category 'Shooting'...
# Processing 'Shoplifting043_x264' in category 'Shoplifting'...
# Processing 'Shoplifting044_x264' in category 'Shoplifting'...
# Processing 'Shoplifting045_x264' in category 'Shoplifting'...
# Processing 'Shoplifting047_x264' in category 'Shoplifting'...
# Processing 'Shoplifting048_x264' in category 'Shoplifting'...
# Processing 'Shoplifting049_x264' in category 'Shoplifting'...
# Processing 'Shoplifting050_x264' in category 'Shoplifting'...
# Processing 'Shoplifting051_x264' in category 'Shoplifting'...
# Processing 'Shoplifting052_x264' in category 'Shoplifting'...
# Processing 'Shoplifting053_x264' in category 'Shoplifting'...
# Processing 'Shoplifting054_x264' in category 'Shoplifting'...
# Processing 'Shoplifting055_x264' in category 'Shoplifting'...
# Processing 'Stealing093_x264' in category 'Stealing'...
# Processing 'Stealing094_x264' in category 'Stealing'...
# Processing 'Stealing095_x264' in category 'Stealing'...
# Processing 'Stealing096_x264' in category 'Stealing'...
# Processing 'Stealing097_x264' in category 'Stealing'...
# Processing 'Stealing098_x264' in category 'Stealing'...
# Processing 'Stealing100_x264' in category 'Stealing'...
# Processing 'Stealing101_x264' in category 'Stealing'...
# Processing 'Stealing102_x264' in category 'Stealing'...
# Processing 'Stealing103_x264' in category 'Stealing'...
# Processing 'Stealing104_x264' in category 'Stealing'...
# Processing 'Stealing105_x264' in category 'Stealing'...
# Processing 'Stealing106_x264' in category 'Stealing'...
# Processing 'Stealing107_x264' in category 'Stealing'...
# Processing 'Stealing108_x264' in category 'Stealing'...
# Processing 'Stealing109_x264' in category 'Stealing'...
# Processing 'Stealing110_x264' in category 'Stealing'...
# Processing 'Stealing111_x264' in category 'Stealing'...
# Processing 'Stealing112_x264' in category 'Stealing'...
# Processing 'Stealing113_x264' in category 'Stealing'...
# Processing 'Stealing114_x264' in category 'Stealing'...
# Processing 'Vandalism044_x264' in category 'Vandalism'...
# Processing 'Vandalism045_x264' in category 'Vandalism'...
# Processing 'Vandalism046_x264' in category 'Vandalism'...
# Processing 'Vandalism047_x264' in category 'Vandalism'...
# Processing 'Vandalism048_x264' in category 'Vandalism'...
# Processing 'Vandalism049_x264' in category 'Vandalism'...
# Processing 'Vandalism050_x264' in category 'Vandalism'...
# Processing 'Normal_Videos_934_x264' in category 'Normal'...
# Processing 'Normal_Videos_935_x264' in category 'Normal'...
# Processing 'Normal_Videos_936_x264' in category 'Normal'...
# Processing 'Normal_Videos_938_x264' in category 'Normal'...
# Processing 'Normal_Videos_939_x264' in category 'Normal'...
# Processing 'Normal_Videos_940_x264' in category 'Normal'...
# Processing 'Normal_Videos_941_x264' in category 'Normal'...
# Processing 'Normal_Videos_943_x264' in category 'Normal'...
# Processing 'Normal_Videos_944_x264' in category 'Normal'...
# Processing 'Normal_Videos639_x264' in category 'Normal'...
# Processing 'Normal_Videos640_x264' in category 'Normal'...
# Processing 'Normal_Videos643_x264' in category 'Normal'...
# Processing 'Normal_Videos644_x264' in category 'Normal'...
# Processing 'Normal_Videos645_x264' in category 'Normal'...
# Processing 'Normal_Videos646_x264' in category 'Normal'...
# Processing 'Normal_Videos647_x264' in category 'Normal'...
# Processing 'Normal_Videos648_x264' in category 'Normal'...
# Processing 'Normal_Videos649_x264' in category 'Normal'...
# Processing 'Normal_Videos650_x264' in category 'Normal'...
# Processing 'Normal_Videos651_x264' in category 'Normal'...
# Processing 'Normal_Videos652_x264' in category 'Normal'...
# Processing 'Normal_Videos653_x264' in category 'Normal'...
# Processing 'Normal_Videos654_x264' in category 'Normal'...
# Processing 'Normal_Videos655_x264' in category 'Normal'...
# Processing 'Normal_Videos657_x264' in category 'Normal'...
# Processing 'Normal_Videos658_x264' in category 'Normal'...
# Processing 'Normal_Videos659_x264' in category 'Normal'...
# Processing 'Normal_Videos660_x264' in category 'Normal'...
# Processing 'Normal_Videos661_x264' in category 'Normal'...
# Processing 'Normal_Videos662_x264' in category 'Normal'...
# Processing 'Normal_Videos663_x264' in category 'Normal'...
# Processing 'Normal_Videos664_x264' in category 'Normal'...
# Processing 'Normal_Videos665_x264' in category 'Normal'...
# Processing 'Normal_Videos667_x264' in category 'Normal'...
# Processing 'Normal_Videos668_x264' in category 'Normal'...
# Processing 'Normal_Videos669_x264' in category 'Normal'...
# Processing 'Normal_Videos670_x264' in category 'Normal'...
# Processing 'Normal_Videos671_x264' in category 'Normal'...
# Processing 'Normal_Videos672_x264' in category 'Normal'...
# Processing 'Normal_Videos673_x264' in category 'Normal'...
# Processing 'Normal_Videos674_x264' in category 'Normal'...
# Processing 'Normal_Videos675_x264' in category 'Normal'...
# Processing 'Normal_Videos676_x264' in category 'Normal'...
# Processing 'Normal_Videos677_x264' in category 'Normal'...
# Processing 'Normal_Videos678_x264' in category 'Normal'...
# Processing 'Normal_Videos679_x264' in category 'Normal'...
# Processing 'Normal_Videos680_x264' in category 'Normal'...
# Processing 'Normal_Videos681_x264' in category 'Normal'...
# Processing 'Normal_Videos682_x264' in category 'Normal'...
# Processing 'Normal_Videos683_x264' in category 'Normal'...
# Processing 'Normal_Videos684_x264' in category 'Normal'...
# Processing 'Normal_Videos685_x264' in category 'Normal'...
# Processing 'Normal_Videos687_x264' in category 'Normal'...
# Processing 'Normal_Videos689_x264' in category 'Normal'...
# Processing 'Normal_Videos691_x264' in category 'Normal'...
# Processing 'Normal_Videos692_x264' in category 'Normal'...
# Processing 'Normal_Videos693_x264' in category 'Normal'...
# Processing 'Normal_Videos694_x264' in category 'Normal'...
# Processing 'Normal_Videos695_x264' in category 'Normal'...
# Processing 'Normal_Videos697_x264' in category 'Normal'...
# Processing 'Normal_Videos698_x264' in category 'Normal'...
# Processing 'Normal_Videos699_x264' in category 'Normal'...
# Processing 'Normal_Videos700_x264' in category 'Normal'...
# Processing 'Normal_Videos701_x264' in category 'Normal'...
# Processing 'Normal_Videos703_x264' in category 'Normal'...
# Processing 'Normal_Videos705_x264' in category 'Normal'...
# Processing 'Normal_Videos706_x264' in category 'Normal'...
# Processing 'Normal_Videos707_x264' in category 'Normal'...
# Processing 'Normal_Videos708_x264' in category 'Normal'...
# Processing 'Normal_Videos709_x264' in category 'Normal'...
# Processing 'Normal_Videos711_x264' in category 'Normal'...
# Processing 'Normal_Videos712_x264' in category 'Normal'...
# Processing 'Normal_Videos713_x264' in category 'Normal'...
# Processing 'Normal_Videos714_x264' in category 'Normal'...
# Processing 'Normal_Videos715_x264' in category 'Normal'...
# Processing 'Normal_Videos718_x264' in category 'Normal'...
# Processing 'Normal_Videos719_x264' in category 'Normal'...
# Processing 'Normal_Videos720_x264' in category 'Normal'...
# Processing 'Normal_Videos721_x264' in category 'Normal'...
# Processing 'Normal_Videos723_x264' in category 'Normal'...
# Processing 'Normal_Videos724_x264' in category 'Normal'...
# Processing 'Normal_Videos726_x264' in category 'Normal'...
# Processing 'Normal_Videos727_x264' in category 'Normal'...
# Processing 'Normal_Videos728_x264' in category 'Normal'...
# Processing 'Normal_Videos729_x264' in category 'Normal'...
# Processing 'Normal_Videos730_x264' in category 'Normal'...
# Processing 'Normal_Videos731_x264' in category 'Normal'...
# Processing 'Normal_Videos732_x264' in category 'Normal'...
# Processing 'Normal_Videos733_x264' in category 'Normal'...
# Processing 'Normal_Videos734_x264' in category 'Normal'...
# Processing 'Normal_Videos735_x264' in category 'Normal'...
# Processing 'Normal_Videos736_x264' in category 'Normal'...
# Processing 'Normal_Videos737_x264' in category 'Normal'...
# Processing 'Normal_Videos738_x264' in category 'Normal'...
# Processing 'Normal_Videos739_x264' in category 'Normal'...
# Processing 'Normal_Videos740_x264' in category 'Normal'...
# Processing 'Normal_Videos741_x264' in category 'Normal'...
# Processing 'Normal_Videos742_x264' in category 'Normal'...
# Processing 'Normal_Videos743_x264' in category 'Normal'...
# Processing 'Normal_Videos744_x264' in category 'Normal'...
# Processing 'Normal_Videos746_x264' in category 'Normal'...
# Processing 'Normal_Videos747_x264' in category 'Normal'...
# Processing 'Normal_Videos748_x264' in category 'Normal'...
# Processing 'Normal_Videos749_x264' in category 'Normal'...
# Processing 'Normal_Videos750_x264' in category 'Normal'...
# Processing 'Normal_Videos751_x264' in category 'Normal'...
# Processing 'Normal_Videos752_x264' in category 'Normal'...
# Processing 'Normal_Videos753_x264' in category 'Normal'...
# Processing 'Normal_Videos754_x264' in category 'Normal'...
# Processing 'Normal_Videos756_x264' in category 'Normal'...
# [INFO] Reached 110 videos in category 'Normal'.
#
# [INFO] Saved 215 extracted frames to 'Val_image_captions.csv'.

# %%
import os
import cv2
import json
import re
import pandas as pd
from collections import defaultdict

# 1) Install & Import PySceneDetect
# !pip install scenedetect --quiet
from scenedetect import VideoManager, SceneManager
from scenedetect.detectors import ContentDetector
from scenedetect.scene_manager import StatsManager

# Paths for annotations, videos, output frames, and CSV file
ANNOTATIONS_FILE = '/kaggle/input/ucaucf-crime-annotation-dataset/UCFCrime_Test.json'
VIDEOS_DIR = '/kaggle/input/ucaucf-crime-annotation-dataset/UCF_Crimes/UCF_Crimes/Videos'
OUTPUT_DIR = 'test_output_frames'
CSV_FILE = 'test_image_captions.csv'

# Allowed video file extensions
VIDEO_EXTENSIONS = ['.mp4', '.avi', '.mov', '.mkv']

# Max videos per category
MAX_PER_CATEGORY = 150

def find_video_file(video_name, base_dir, exts):
    """
    Search recursively under `base_dir` for a file that has the same
    (base) name as `video_name` and one of the allowed `exts`.
    Returns the full path if found, else None.
    """
    for root, dirs, files in os.walk(base_dir):
        for file in files:
            name, ext = os.path.splitext(file)
            if name == video_name and ext.lower() in exts:
                return os.path.join(root, file)
    return None

def extract_category_from_key(video_key):
    """
    Extract the category name from the start of the video key.
    e.g., 'Abuse001_x264' -> 'Abuse'.
    """
    match = re.match(r'([A-Za-z]+)', video_key)
    if match:
        return match.group(1)
    return "Unknown"

# Create output directory
os.makedirs(OUTPUT_DIR, exist_ok=True)

# Load JSON annotations
with open(ANNOTATIONS_FILE, 'r') as f:
    annotations = json.load(f)

category_count = defaultdict(int)
data_entries = []

def detect_scenes_and_extract_frames(
    video_path, video_name, category,
    timestamps, sentences,
    frames_per_scene=3  # <--- We want multiple frames per scene
):
    """
    Use PySceneDetect to detect scene boundaries and extract multiple frames 
    from each scene. For each frame, we find the matching caption based on timestamps.
    """
    # --- Setup PySceneDetect ---
    video_manager = VideoManager([video_path])
    stats_manager = StatsManager()
    scene_manager = SceneManager(stats_manager)
    
    # Adjust threshold to tune sensitivity
    scene_manager.add_detector(ContentDetector(threshold=30.0))
    
    # Start the video manager & perform scene detection
    video_manager.start()
    scene_manager.detect_scenes(frame_source=video_manager)
    scene_list = scene_manager.get_scene_list()
    
    # Re-open video with OpenCV for frame extraction
    cap = cv2.VideoCapture(video_path)
    fps = cap.get(cv2.CAP_PROP_FPS)
    
    frames_and_captions = []
    
    # For each scene, extract multiple frames
    for scene_idx, scene in enumerate(scene_list):
        start_tc, end_tc = scene
        start_frame = start_tc.get_frames()
        end_frame = end_tc.get_frames()
        scene_length = end_frame - start_frame
        
        # If scene is too short, just skip or pick 1 frame
        if scene_length <= 0:
            continue
        
        # Example: evenly space frames_per_scene frames across the scene
        for i in range(frames_per_scene):
            fraction = i / (frames_per_scene - 1) if frames_per_scene > 1 else 0
            frame_idx = start_frame + int(scene_length * fraction)
            
            # Set video position & read the frame
            cap.set(cv2.CAP_PROP_POS_FRAMES, frame_idx)
            ret, frame = cap.read()
            if not ret:
                continue
            
            # Current time in seconds
            current_time_sec = frame_idx / fps
            
            # Find matching caption
            matched_caption = None
            for idx, interval in enumerate(timestamps):
                start_sec, end_sec = interval
                if start_sec <= current_time_sec <= end_sec:
                    matched_caption = sentences[idx]
                    break
            
            if matched_caption:
                image_filename = f"{video_name}_scene{scene_idx}_frame{frame_idx}.jpg"
                image_path = os.path.join(OUTPUT_DIR, image_filename)
                cv2.imwrite(image_path, frame)
                
                frames_and_captions.append({
                    'image_path': image_path,
                    'caption': matched_caption,
                    'video_key': video_name,
                    'category': category,
                    'frame_index': frame_idx
                })
    
    cap.release()
    video_manager.release()
    return frames_and_captions

# Main loop
for video_name, data in annotations.items():
    category = extract_category_from_key(video_name)

    if category_count[category] >= MAX_PER_CATEGORY:
        continue

    video_file = find_video_file(video_name, VIDEOS_DIR, VIDEO_EXTENSIONS)
    if not video_file:
        print(f"[WARNING] Could not find file for video key '{video_name}'")
        continue

    timestamps = data.get("timestamps", [])
    sentences = data.get("sentences", [])

    print(f"Processing '{video_name}' in category '{category}'...")

    frames_captions = detect_scenes_and_extract_frames(
        video_path=video_file,
        video_name=video_name,
        category=category,
        timestamps=timestamps,
        sentences=sentences,
        frames_per_scene=3  # <--- Change this to however many frames you want per scene
    )

    data_entries.extend(frames_captions)
    category_count[category] += 1
    
    if category_count[category] == MAX_PER_CATEGORY:
        print(f"[INFO] Reached {MAX_PER_CATEGORY} videos in category '{category}'.")

# Convert to DataFrame and save
df = pd.DataFrame(data_entries)
df.to_csv(CSV_FILE, index=False)
print(f"[INFO] Saved {len(df)} extracted frames to '{CSV_FILE}'.")
# Out:
# Processing 'Abuse037_x264' in category 'Abuse'...
# Processing 'Abuse038_x264' in category 'Abuse'...
# Processing 'Abuse039_x264' in category 'Abuse'...
# Processing 'Abuse040_x264' in category 'Abuse'...
# Processing 'Abuse041_x264' in category 'Abuse'...
# Processing 'Abuse042_x264' in category 'Abuse'...
# Processing 'Arrest043_x264' in category 'Arrest'...
# Processing 'Arrest044_x264' in category 'Arrest'...
# Processing 'Arrest046_x264' in category 'Arrest'...
# Processing 'Arrest048_x264' in category 'Arrest'...
# Processing 'Arrest049_x264' in category 'Arrest'...
# Processing 'Arrest050_x264' in category 'Arrest'...
# Processing 'Arrest051_x264' in category 'Arrest'...
# Processing 'Arson020_x264' in category 'Arson'...
# Processing 'Arson021_x264' in category 'Arson'...
# Processing 'Arson022_x264' in category 'Arson'...
# Processing 'Arson023_x264' in category 'Arson'...
# Processing 'Arson024_x264' in category 'Arson'...
# Processing 'Arson025_x264' in category 'Arson'...
# Processing 'Arson026_x264' in category 'Arson'...
# Processing 'Arson027_x264' in category 'Arson'...
# Processing 'Arson028_x264' in category 'Arson'...
# Processing 'Arson029_x264' in category 'Arson'...
# Processing 'Arson030_x264' in category 'Arson'...
# Processing 'Arson031_x264' in category 'Arson'...
# Processing 'Arson032_x264' in category 'Arson'...
# Processing 'Arson034_x264' in category 'Arson'...
# Processing 'Arson035_x264' in category 'Arson'...
# Processing 'Arson036_x264' in category 'Arson'...
# Processing 'Arson037_x264' in category 'Arson'...
# Processing 'Arson038_x264' in category 'Arson'...
# Processing 'Arson039_x264' in category 'Arson'...
# Processing 'Assault027_x264' in category 'Assault'...
# Processing 'Assault028_x264' in category 'Assault'...
# Processing 'Assault029_x264' in category 'Assault'...
# Processing 'Assault030_x264' in category 'Assault'...
# Processing 'Assault031_x264' in category 'Assault'...
# Processing 'Assault032_x264' in category 'Assault'...
# Processing 'Assault033_x264' in category 'Assault'...
# Processing 'Assault034_x264' in category 'Assault'...
# Processing 'Assault035_x264' in category 'Assault'...
# Processing 'Assault036_x264' in category 'Assault'...
# Processing 'Assault037_x264' in category 'Assault'...
# Processing 'Assault038_x264' in category 'Assault'...
# Processing 'Assault039_x264' in category 'Assault'...
# Processing 'Assault040_x264' in category 'Assault'...
# Processing 'Burglary065_x264' in category 'Burglary'...
# Processing 'Burglary066_x264' in category 'Burglary'...
# Processing 'Burglary067_x264' in category 'Burglary'...
# Processing 'Burglary068_x264' in category 'Burglary'...
# Processing 'Burglary069_x264' in category 'Burglary'...
# Processing 'Burglary070_x264' in category 'Burglary'...
# Processing 'Burglary071_x264' in category 'Burglary'...
# Processing 'Burglary072_x264' in category 'Burglary'...
# Processing 'Burglary073_x264' in category 'Burglary'...
# Processing 'Burglary074_x264' in category 'Burglary'...
# Processing 'Burglary075_x264' in category 'Burglary'...
# Processing 'Burglary076_x264' in category 'Burglary'...
# Processing 'Burglary077_x264' in category 'Burglary'...
# Processing 'Burglary078_x264' in category 'Burglary'...
# Processing 'Burglary079_x264' in category 'Burglary'...
# Processing 'Burglary080_x264' in category 'Burglary'...
# Processing 'Burglary081_x264' in category 'Burglary'...
# Processing 'Burglary082_x264' in category 'Burglary'...
# Processing 'Burglary083_x264' in category 'Burglary'...
# Processing 'Burglary084_x264' in category 'Burglary'...
# Processing 'Burglary085_x264' in category 'Burglary'...
# Processing 'Burglary086_x264' in category 'Burglary'...
# Processing 'Burglary087_x264' in category 'Burglary'...
# Processing 'Explosion007_x264' in category 'Explosion'...
# Processing 'Explosion008_x264' in category 'Explosion'...
# Processing 'Explosion009_x264' in category 'Explosion'...
# Processing 'Explosion010_x264' in category 'Explosion'...
# Processing 'Explosion011_x264' in category 'Explosion'...
# Processing 'Explosion012_x264' in category 'Explosion'...
# Processing 'Explosion013_x264' in category 'Explosion'...
# Processing 'Explosion014_x264' in category 'Explosion'...
# Processing 'Explosion015_x264' in category 'Explosion'...
# Processing 'Explosion016_x264' in category 'Explosion'...
# Processing 'Explosion017_x264' in category 'Explosion'...
# Processing 'Explosion018_x264' in category 'Explosion'...
# Processing 'Explosion019_x264' in category 'Explosion'...
# Processing 'Explosion020_x264' in category 'Explosion'...
# Processing 'Explosion021_x264' in category 'Explosion'...
# Processing 'Explosion022_x264' in category 'Explosion'...
# Processing 'Explosion023_x264' in category 'Explosion'...
# Processing 'Explosion024_x264' in category 'Explosion'...
# Processing 'Explosion025_x264' in category 'Explosion'...
# Processing 'Explosion026_x264' in category 'Explosion'...
# Processing 'Explosion027_x264' in category 'Explosion'...
# Processing 'Explosion028_x264' in category 'Explosion'...
# Processing 'Explosion029_x264' in category 'Explosion'...
# Processing 'Fighting039_x264' in category 'Fighting'...
# Processing 'Fighting040_x264' in category 'Fighting'...
# Processing 'Fighting041_x264' in category 'Fighting'...
# Processing 'Fighting042_x264' in category 'Fighting'...
# Processing 'Fighting043_x264' in category 'Fighting'...
# Processing 'Fighting044_x264' in category 'Fighting'...
# Processing 'RoadAccidents109_x264' in category 'RoadAccidents'...
# Processing 'RoadAccidents110_x264' in category 'RoadAccidents'...
# Processing 'RoadAccidents111_x264' in category 'RoadAccidents'...
# Processing 'RoadAccidents112_x264' in category 'RoadAccidents'...
# Processing 'RoadAccidents113_x264' in category 'RoadAccidents'...
# Processing 'RoadAccidents114_x264' in category 'RoadAccidents'...
# Processing 'RoadAccidents115_x264' in category 'RoadAccidents'...
# Processing 'RoadAccidents116_x264' in category 'RoadAccidents'...
# Processing 'RoadAccidents117_x264' in category 'RoadAccidents'...
# Processing 'RoadAccidents118_x264' in category 'RoadAccidents'...
# Processing 'RoadAccidents119_x264' in category 'RoadAccidents'...
# Processing 'RoadAccidents120_x264' in category 'RoadAccidents'...
# Processing 'RoadAccidents121_x264' in category 'RoadAccidents'...
# Processing 'RoadAccidents122_x264' in category 'RoadAccidents'...
# Processing 'RoadAccidents123_x264' in category 'RoadAccidents'...
# Processing 'RoadAccidents124_x264' in category 'RoadAccidents'...
# Processing 'RoadAccidents125_x264' in category 'RoadAccidents'...
# Processing 'RoadAccidents126_x264' in category 'RoadAccidents'...
# Processing 'RoadAccidents127_x264' in category 'RoadAccidents'...
# Processing 'RoadAccidents128_x264' in category 'RoadAccidents'...
# Processing 'RoadAccidents129_x264' in category 'RoadAccidents'...
# Processing 'RoadAccidents130_x264' in category 'RoadAccidents'...
# Processing 'RoadAccidents131_x264' in category 'RoadAccidents'...
# Processing 'RoadAccidents132_x264' in category 'RoadAccidents'...
# Processing 'RoadAccidents133_x264' in category 'RoadAccidents'...
# Processing 'RoadAccidents134_x264' in category 'RoadAccidents'...
# Processing 'RoadAccidents135_x264' in category 'RoadAccidents'...
# Processing 'RoadAccidents136_x264' in category 'RoadAccidents'...
# Processing 'RoadAccidents137_x264' in category 'RoadAccidents'...
# Processing 'RoadAccidents138_x264' in category 'RoadAccidents'...
# Processing 'RoadAccidents139_x264' in category 'RoadAccidents'...
# Processing 'RoadAccidents140_x264' in category 'RoadAccidents'...
# Processing 'RoadAccidents141_x264' in category 'RoadAccidents'...
# Processing 'RoadAccidents142_x264' in category 'RoadAccidents'...
# Processing 'RoadAccidents143_x264' in category 'RoadAccidents'...
# Processing 'Robbery085_x264' in category 'Robbery'...
# Processing 'Robbery086_x264' in category 'Robbery'...
# Processing 'Robbery087_x264' in category 'Robbery'...
# Processing 'Robbery088_x264' in category 'Robbery'...
# Processing 'Robbery089_x264' in category 'Robbery'...
# Processing 'Robbery090_x264' in category 'Robbery'...
# Processing 'Robbery091_x264' in category 'Robbery'...
# Processing 'Robbery092_x264' in category 'Robbery'...
# Processing 'Robbery093_x264' in category 'Robbery'...
# Processing 'Robbery094_x264' in category 'Robbery'...
# Processing 'Robbery095_x264' in category 'Robbery'...
# Processing 'Robbery096_x264' in category 'Robbery'...
# Processing 'Robbery097_x264' in category 'Robbery'...
# Processing 'Robbery098_x264' in category 'Robbery'...
# Processing 'Robbery099_x264' in category 'Robbery'...
# Processing 'Robbery100_x264' in category 'Robbery'...
# Processing 'Robbery101_x264' in category 'Robbery'...
# Processing 'Robbery102_x264' in category 'Robbery'...
# Processing 'Robbery103_x264' in category 'Robbery'...
# Processing 'Robbery104_x264' in category 'Robbery'...
# Processing 'Robbery105_x264' in category 'Robbery'...
# Processing 'Robbery106_x264' in category 'Robbery'...
# Processing 'Robbery107_x264' in category 'Robbery'...
# Processing 'Robbery108_x264' in category 'Robbery'...
# Processing 'Robbery109_x264' in category 'Robbery'...
# Processing 'Robbery110_x264' in category 'Robbery'...
# Processing 'Robbery111_x264' in category 'Robbery'...
# Processing 'Robbery112_x264' in category 'Robbery'...
# Processing 'Shooting033_x264' in category 'Shooting'...
# Processing 'Shooting034_x264' in category 'Shooting'...
# Processing 'Shooting036_x264' in category 'Shooting'...
# Processing 'Shooting037_x264' in category 'Shooting'...
# Processing 'Shooting038_x264' in category 'Shooting'...
# Processing 'Shooting039_x264' in category 'Shooting'...
# Processing 'Shooting040_x264' in category 'Shooting'...
# Processing 'Shooting041_x264' in category 'Shooting'...
# Processing 'Shooting042_x264' in category 'Shooting'...
# Processing 'Shooting043_x264' in category 'Shooting'...
# Processing 'Shooting044_x264' in category 'Shooting'...
# Processing 'Shooting046_x264' in category 'Shooting'...
# Processing 'Shoplifting034_x264' in category 'Shoplifting'...
# Processing 'Shoplifting036_x264' in category 'Shoplifting'...
# Processing 'Shoplifting037_x264' in category 'Shoplifting'...
# Processing 'Shoplifting038_x264' in category 'Shoplifting'...
# Processing 'Shoplifting039_x264' in category 'Shoplifting'...
# Processing 'Shoplifting040_x264' in category 'Shoplifting'...
# Processing 'Shoplifting041_x264' in category 'Shoplifting'...
# Processing 'Shoplifting042_x264' in category 'Shoplifting'...
# Processing 'Stealing078_x264' in category 'Stealing'...
# Processing 'Stealing079_x264' in category 'Stealing'...
# Processing 'Stealing080_x264' in category 'Stealing'...
# Processing 'Stealing081_x264' in category 'Stealing'...
# Processing 'Stealing082_x264' in category 'Stealing'...
# Processing 'Stealing083_x264' in category 'Stealing'...
# Processing 'Stealing084_x264' in category 'Stealing'...
# Processing 'Stealing086_x264' in category 'Stealing'...
# Processing 'Stealing087_x264' in category 'Stealing'...
# Processing 'Stealing088_x264' in category 'Stealing'...
# Processing 'Stealing089_x264' in category 'Stealing'...
# Processing 'Stealing091_x264' in category 'Stealing'...
# Processing 'Stealing092_x264' in category 'Stealing'...
# Processing 'Vandalism031_x264' in category 'Vandalism'...
# Processing 'Vandalism032_x264' in category 'Vandalism'...
# Processing 'Vandalism033_x264' in category 'Vandalism'...
# Processing 'Vandalism034_x264' in category 'Vandalism'...
# Processing 'Vandalism035_x264' in category 'Vandalism'...
# Processing 'Vandalism036_x264' in category 'Vandalism'...
# Processing 'Vandalism038_x264' in category 'Vandalism'...
# Processing 'Vandalism039_x264' in category 'Vandalism'...
# Processing 'Vandalism040_x264' in category 'Vandalism'...
# Processing 'Vandalism041_x264' in category 'Vandalism'...
# Processing 'Vandalism042_x264' in category 'Vandalism'...
# Processing 'Vandalism043_x264' in category 'Vandalism'...
# Processing 'Normal_Videos_924_x264' in category 'Normal'...
# Processing 'Normal_Videos_925_x264' in category 'Normal'...
# Processing 'Normal_Videos_926_x264' in category 'Normal'...
# Processing 'Normal_Videos_928_x264' in category 'Normal'...
# Processing 'Normal_Videos_929_x264' in category 'Normal'...
# Processing 'Normal_Videos_930_x264' in category 'Normal'...
# Processing 'Normal_Videos_931_x264' in category 'Normal'...
# Processing 'Normal_Videos_932_x264' in category 'Normal'...
# Processing 'Normal_Videos_933_x264' in category 'Normal'...
# Processing 'Normal_Videos534_x264' in category 'Normal'...
# Processing 'Normal_Videos535_x264' in category 'Normal'...
# Processing 'Normal_Videos536_x264' in category 'Normal'...
# Processing 'Normal_Videos537_x264' in category 'Normal'...
# Processing 'Normal_Videos538_x264' in category 'Normal'...
# Processing 'Normal_Videos539_x264' in category 'Normal'...
# Processing 'Normal_Videos540_x264' in category 'Normal'...
# Processing 'Normal_Videos541_x264' in category 'Normal'...
# Processing 'Normal_Videos542_x264' in category 'Normal'...
# Processing 'Normal_Videos544_x264' in category 'Normal'...
# Processing 'Normal_Videos545_x264' in category 'Normal'...
# Processing 'Normal_Videos546_x264' in category 'Normal'...
# Processing 'Normal_Videos547_x264' in category 'Normal'...
# Processing 'Normal_Videos548_x264' in category 'Normal'...
# Processing 'Normal_Videos549_x264' in category 'Normal'...
# Processing 'Normal_Videos550_x264' in category 'Normal'...
# Processing 'Normal_Videos551_x264' in category 'Normal'...
# Processing 'Normal_Videos552_x264' in category 'Normal'...
# Processing 'Normal_Videos553_x264' in category 'Normal'...
# Processing 'Normal_Videos554_x264' in category 'Normal'...
# Processing 'Normal_Videos555_x264' in category 'Normal'...
# Processing 'Normal_Videos556_x264' in category 'Normal'...
# Processing 'Normal_Videos557_x264' in category 'Normal'...
# Processing 'Normal_Videos558_x264' in category 'Normal'...
# Processing 'Normal_Videos559_x264' in category 'Normal'...
# Processing 'Normal_Videos560_x264' in category 'Normal'...
# Processing 'Normal_Videos561_x264' in category 'Normal'...
# Processing 'Normal_Videos562_x264' in category 'Normal'...
# Processing 'Normal_Videos563_x264' in category 'Normal'...
# Processing 'Normal_Videos564_x264' in category 'Normal'...
# Processing 'Normal_Videos565_x264' in category 'Normal'...
# Processing 'Normal_Videos566_x264' in category 'Normal'...
# Processing 'Normal_Videos567_x264' in category 'Normal'...
# Processing 'Normal_Videos568_x264' in category 'Normal'...
# Processing 'Normal_Videos569_x264' in category 'Normal'...
# Processing 'Normal_Videos570_x264' in category 'Normal'...
# Processing 'Normal_Videos571_x264' in category 'Normal'...
# Processing 'Normal_Videos572_x264' in category 'Normal'...
# Processing 'Normal_Videos573_x264' in category 'Normal'...
# Processing 'Normal_Videos574_x264' in category 'Normal'...
# Processing 'Normal_Videos575_x264' in category 'Normal'...
# Processing 'Normal_Videos577_x264' in category 'Normal'...
# Processing 'Normal_Videos578_x264' in category 'Normal'...
# Processing 'Normal_Videos579_x264' in category 'Normal'...
# Processing 'Normal_Videos580_x264' in category 'Normal'...
# Processing 'Normal_Videos581_x264' in category 'Normal'...
# Processing 'Normal_Videos582_x264' in category 'Normal'...
# Processing 'Normal_Videos583_x264' in category 'Normal'...
# Processing 'Normal_Videos584_x264' in category 'Normal'...
# Processing 'Normal_Videos585_x264' in category 'Normal'...
# Processing 'Normal_Videos586_x264' in category 'Normal'...
# Processing 'Normal_Videos587_x264' in category 'Normal'...
# Processing 'Normal_Videos588_x264' in category 'Normal'...
# Processing 'Normal_Videos589_x264' in category 'Normal'...
# Processing 'Normal_Videos590_x264' in category 'Normal'...
# Processing 'Normal_Videos591_x264' in category 'Normal'...
# Processing 'Normal_Videos592_x264' in category 'Normal'...
# Processing 'Normal_Videos593_x264' in category 'Normal'...
# Processing 'Normal_Videos594_x264' in category 'Normal'...
# Processing 'Normal_Videos598_x264' in category 'Normal'...
# Processing 'Normal_Videos599_x264' in category 'Normal'...
# Processing 'Normal_Videos600_x264' in category 'Normal'...
# Processing 'Normal_Videos601_x264' in category 'Normal'...
# Processing 'Normal_Videos602_x264' in category 'Normal'...
# Processing 'Normal_Videos604_x264' in category 'Normal'...
# Processing 'Normal_Videos605_x264' in category 'Normal'...
# Processing 'Normal_Videos608_x264' in category 'Normal'...
# Processing 'Normal_Videos609_x264' in category 'Normal'...
# Processing 'Normal_Videos610_x264' in category 'Normal'...
# Processing 'Normal_Videos611_x264' in category 'Normal'...
# Processing 'Normal_Videos612_x264' in category 'Normal'...
# Processing 'Normal_Videos613_x264' in category 'Normal'...
# Processing 'Normal_Videos614_x264' in category 'Normal'...
# Processing 'Normal_Videos615_x264' in category 'Normal'...
# Processing 'Normal_Videos616_x264' in category 'Normal'...
# Processing 'Normal_Videos617_x264' in category 'Normal'...
# Processing 'Normal_Videos618_x264' in category 'Normal'...
# Processing 'Normal_Videos619_x264' in category 'Normal'...
# Processing 'Normal_Videos620_x264' in category 'Normal'...
# Processing 'Normal_Videos622_x264' in category 'Normal'...
# Processing 'Normal_Videos623_x264' in category 'Normal'...
# Processing 'Normal_Videos624_x264' in category 'Normal'...
# Processing 'Normal_Videos625_x264' in category 'Normal'...
# Processing 'Normal_Videos626_x264' in category 'Normal'...
# Processing 'Normal_Videos627_x264' in category 'Normal'...
# Processing 'Normal_Videos628_x264' in category 'Normal'...
# Processing 'Normal_Videos629_x264' in category 'Normal'...
# Processing 'Normal_Videos630_x264' in category 'Normal'...
# Processing 'Normal_Videos631_x264' in category 'Normal'...
# Processing 'Normal_Videos632_x264' in category 'Normal'...
# Processing 'Normal_Videos633_x264' in category 'Normal'...
# Processing 'Normal_Videos635_x264' in category 'Normal'...
# Processing 'Normal_Videos636_x264' in category 'Normal'...
# Processing 'Normal_Videos637_x264' in category 'Normal'...
# Processing 'Normal_Videos638_x264' in category 'Normal'...
# [INFO] Saved 775 extracted frames to 'test_image_captions.csv'.

# %% [markdown]
# ## Extract Frames From all Videos and save them in 1 Folder

# %%
import os
import cv2
import json
import re
import pandas as pd
from collections import defaultdict

# Paths for annotations, videos, output frames, and CSV file
ANNOTATIONS_FILE = '/kaggle/input/ucaucf-crime-annotation-dataset/UCFCrime_Train.json'
VIDEOS_DIR = '/kaggle/input/ucaucf-crime-annotation-dataset/UCF_Crimes/UCF_Crimes/Videos'    # e.g., "./UCF_Crimes/Videos/"
OUTPUT_DIR = 'output-frames'           # All images will be saved in one folder
CSV_FILE = 'train_image_captions.csv'    # CSV file to save image path and caption pairs

# List of possible file extensions in your dataset
VIDEO_EXTENSIONS = ['.mp4', '.avi', '.mov', '.mkv']

def find_video_file(video_name, base_dir, exts):
    """
    Search recursively under `base_dir` for a file that has the same
    (base) name as `video_name` and one of the allowed `exts`.
    Returns the full path if found, else None.
    """
    for root, dirs, files in os.walk(base_dir):
        for file in files:
            name, ext = os.path.splitext(file)
            if name == video_name and ext.lower() in exts:
                return os.path.join(root, file)
    return None

def extract_category_from_key(video_key):
    """
    Extract the category name from the start of the video key.
    For example, 'Abuse001_x264' -> 'Abuse'
    Adjust this logic if your naming convention is different.
    """
    match = re.match(r'([A-Za-z]+)', video_key)
    if match:
        return match.group(1)
    return "Unknown"

# Create the output directory if it doesn't exist
os.makedirs(OUTPUT_DIR, exist_ok=True)

# Load the JSON annotations
with open(ANNOTATIONS_FILE, 'r') as f:
    annotations = json.load(f)

# List to collect dictionaries with image paths and captions
data_entries = []

# Iterate over each video entry in the JSON
for video_name, data in annotations.items():
    # Identify the category from the video key
    category = extract_category_from_key(video_name)

    # Attempt to find the actual video file in subfolders
    video_file = find_video_file(video_name, VIDEOS_DIR, VIDEO_EXTENSIONS)
    if not video_file:
        print(f"[WARNING] Could not find file for video key '{video_name}'")
        continue

    # Try to open the video
    cap = cv2.VideoCapture(video_file)
    if not cap.isOpened():
        print(f"[ERROR] Unable to open video file: {video_file}")
        continue

    fps = cap.get(cv2.CAP_PROP_FPS)
    print(f"Processing '{video_name}' in category '{category}' at {fps} fps.")

    # Get timestamps and sentences lists
    timestamps = data.get("timestamps", [])
    sentences = data.get("sentences", [])

    frame_index = 0
    while True:
        ret, frame = cap.read()
        if not ret:
            break  # End of video

        # Sample every 20th frame (modify this value as needed)
        if frame_index % 20 == 0:
            current_time = frame_index / fps
            caption = None

            # Determine which timestamp interval covers the current frame time
            for idx, interval in enumerate(timestamps):
                start, end = interval
                if start <= current_time <= end:
                    caption = sentences[idx]
                    break

            # If a caption is found, save the frame and record the data
            if caption is not None:
                image_filename = f"{video_name}_frame{frame_index}.jpg"
                image_path = os.path.join(OUTPUT_DIR, image_filename)
                cv2.imwrite(image_path, frame)

                data_entries.append({
                    'image_path': image_path,
                    'caption': caption,
                    'video_key': video_name,
                    'category': category,
                    'frame_index': frame_index
                })
                #print(f"Saved: {image_path}, Caption: {caption}")

        frame_index += 1

    cap.release()

# Convert the collected data into a DataFrame and save as a CSV file
df = pd.DataFrame(data_entries)
df.to_csv(CSV_FILE, index=False)
print(f"Data saved to {CSV_FILE}")
# Out:
# Processing 'Abuse001_x264' in category 'Abuse' at 30.0 fps.
# Processing 'Abuse002_x264' in category 'Abuse' at 30.0 fps.
# Processing 'Abuse003_x264' in category 'Abuse' at 30.0 fps.
# Processing 'Abuse004_x264' in category 'Abuse' at 30.0 fps.
# Processing 'Abuse005_x264' in category 'Abuse' at 30.0 fps.
# Processing 'Abuse006_x264' in category 'Abuse' at 30.0 fps.
# Processing 'Abuse007_x264' in category 'Abuse' at 30.0 fps.
# Processing 'Abuse008_x264' in category 'Abuse' at 30.0 fps.
# Processing 'Abuse009_x264' in category 'Abuse' at 30.0 fps.
# Processing 'Abuse010_x264' in category 'Abuse' at 30.0 fps.
# Processing 'Abuse011_x264' in category 'Abuse' at 30.0 fps.
# Processing 'Abuse012_x264' in category 'Abuse' at 30.0 fps.
# Processing 'Abuse013_x264' in category 'Abuse' at 30.0 fps.
# Processing 'Abuse014_x264' in category 'Abuse' at 30.0 fps.
# Processing 'Abuse015_x264' in category 'Abuse' at 30.0 fps.
# Processing 'Abuse016_x264' in category 'Abuse' at 30.0 fps.
# Processing 'Abuse017_x264' in category 'Abuse' at 30.0 fps.
# Processing 'Abuse018_x264' in category 'Abuse' at 30.0 fps.
# Processing 'Abuse019_x264' in category 'Abuse' at 30.0 fps.
# Processing 'Abuse020_x264' in category 'Abuse' at 30.0 fps.
# Processing 'Abuse021_x264' in category 'Abuse' at 30.0 fps.
# Processing 'Abuse022_x264' in category 'Abuse' at 30.0 fps.
# Processing 'Abuse023_x264' in category 'Abuse' at 30.0 fps.
# Processing 'Abuse024_x264' in category 'Abuse' at 30.0 fps.
# Processing 'Abuse025_x264' in category 'Abuse' at 30.0 fps.
# Processing 'Abuse026_x264' in category 'Abuse' at 30.0 fps.
# Processing 'Abuse027_x264' in category 'Abuse' at 30.0 fps.
# Processing 'Abuse028_x264' in category 'Abuse' at 30.0 fps.
# Processing 'Abuse029_x264' in category 'Abuse' at 30.0 fps.
# Processing 'Abuse030_x264' in category 'Abuse' at 30.0 fps.
# Processing 'Abuse031_x264' in category 'Abuse' at 30.0 fps.
# Processing 'Abuse032_x264' in category 'Abuse' at 30.0 fps.
# Processing 'Abuse033_x264' in category 'Abuse' at 30.0 fps.
# Processing 'Abuse034_x264' in category 'Abuse' at 30.0 fps.
# Processing 'Abuse035_x264' in category 'Abuse' at 30.0 fps.
# Processing 'Abuse036_x264' in category 'Abuse' at 30.0 fps.
# Processing 'Arrest001_x264' in category 'Arrest' at 30.0 fps.
# Processing 'Arrest002_x264' in category 'Arrest' at 30.0 fps.
# Processing 'Arrest003_x264' in category 'Arrest' at 30.0 fps.
# Processing 'Arrest004_x264' in category 'Arrest' at 30.0 fps.
# Processing 'Arrest005_x264' in category 'Arrest' at 30.0 fps.
# Processing 'Arrest006_x264' in category 'Arrest' at 30.0 fps.
# Processing 'Arrest007_x264' in category 'Arrest' at 30.0 fps.
# Processing 'Arrest008_x264' in category 'Arrest' at 30.0 fps.
# Processing 'Arrest009_x264' in category 'Arrest' at 30.0 fps.
# Processing 'Arrest010_x264' in category 'Arrest' at 30.0 fps.
# Processing 'Arrest011_x264' in category 'Arrest' at 30.0 fps.
# Processing 'Arrest012_x264' in category 'Arrest' at 30.0 fps.
# Processing 'Arrest013_x264' in category 'Arrest' at 30.0 fps.
# Processing 'Arrest014_x264' in category 'Arrest' at 30.0 fps.
# Processing 'Arrest015_x264' in category 'Arrest' at 30.0 fps.
# Processing 'Arrest016_x264' in category 'Arrest' at 30.0 fps.
# Processing 'Arrest017_x264' in category 'Arrest' at 30.0 fps.
# Processing 'Arrest018_x264' in category 'Arrest' at 30.0 fps.
# Processing 'Arrest019_x264' in category 'Arrest' at 30.0 fps.
# Processing 'Arrest020_x264' in category 'Arrest' at 30.0 fps.
# Processing 'Arrest021_x264' in category 'Arrest' at 30.0 fps.
# Processing 'Arrest022_x264' in category 'Arrest' at 30.0 fps.
# Processing 'Arrest023_x264' in category 'Arrest' at 30.0 fps.
# Processing 'Arrest024_x264' in category 'Arrest' at 30.0 fps.
# Processing 'Arrest025_x264' in category 'Arrest' at 30.0 fps.
# Processing 'Arrest026_x264' in category 'Arrest' at 30.0 fps.
# Processing 'Arrest027_x264' in category 'Arrest' at 30.0 fps.
# Processing 'Arrest028_x264' in category 'Arrest' at 30.0 fps.
# Processing 'Arrest029_x264' in category 'Arrest' at 30.0 fps.
# Processing 'Arrest030_x264' in category 'Arrest' at 30.0 fps.
# Processing 'Arrest031_x264' in category 'Arrest' at 30.0 fps.
# Processing 'Arrest032_x264' in category 'Arrest' at 30.0 fps.
# Processing 'Arrest033_x264' in category 'Arrest' at 30.0 fps.
# Processing 'Arrest034_x264' in category 'Arrest' at 30.0 fps.
# Processing 'Arrest035_x264' in category 'Arrest' at 30.0 fps.
# Processing 'Arrest036_x264' in category 'Arrest' at 30.0 fps.
# Processing 'Arrest037_x264' in category 'Arrest' at 30.0 fps.
# Processing 'Arrest038_x264' in category 'Arrest' at 30.0 fps.
# Processing 'Arrest039_x264' in category 'Arrest' at 30.0 fps.
# Processing 'Arrest040_x264' in category 'Arrest' at 30.0 fps.
# Processing 'Arrest041_x264' in category 'Arrest' at 30.0 fps.
# Processing 'Arrest042_x264' in category 'Arrest' at 30.0 fps.
# Processing 'Arson001_x264' in category 'Arson' at 30.0 fps.
# Processing 'Arson002_x264' in category 'Arson' at 30.0 fps.
# Processing 'Arson003_x264' in category 'Arson' at 30.0 fps.
# Processing 'Arson005_x264' in category 'Arson' at 30.0 fps.
# Processing 'Arson006_x264' in category 'Arson' at 30.0 fps.
# Processing 'Arson007_x264' in category 'Arson' at 30.0 fps.
# Processing 'Arson008_x264' in category 'Arson' at 30.0 fps.
# Processing 'Arson009_x264' in category 'Arson' at 30.0 fps.
# Processing 'Arson010_x264' in category 'Arson' at 30.0 fps.
# Processing 'Arson011_x264' in category 'Arson' at 30.0 fps.
# Processing 'Arson012_x264' in category 'Arson' at 30.0 fps.
# Processing 'Arson013_x264' in category 'Arson' at 30.0 fps.
# Processing 'Arson014_x264' in category 'Arson' at 30.0 fps.
# Processing 'Arson015_x264' in category 'Arson' at 30.0 fps.
# Processing 'Arson016_x264' in category 'Arson' at 30.0 fps.
# Processing 'Arson017_x264' in category 'Arson' at 30.0 fps.
# Processing 'Arson018_x264' in category 'Arson' at 30.0 fps.
# Processing 'Arson019_x264' in category 'Arson' at 30.0 fps.
# Processing 'Assault001_x264' in category 'Assault' at 30.0 fps.
# Processing 'Assault002_x264' in category 'Assault' at 30.0 fps.
# Processing 'Assault003_x264' in category 'Assault' at 30.0 fps.
# Processing 'Assault004_x264' in category 'Assault' at 30.0 fps.
# Processing 'Assault005_x264' in category 'Assault' at 30.0 fps.
# Processing 'Assault006_x264' in category 'Assault' at 30.0 fps.
# Processing 'Assault007_x264' in category 'Assault' at 30.0 fps.
# Processing 'Assault008_x264' in category 'Assault' at 30.0 fps.
# Processing 'Assault009_x264' in category 'Assault' at 30.0 fps.
# Processing 'Assault010_x264' in category 'Assault' at 30.0 fps.
# Processing 'Assault011_x264' in category 'Assault' at 30.0 fps.
# Processing 'Assault012_x264' in category 'Assault' at 30.0 fps.
# Processing 'Assault013_x264' in category 'Assault' at 30.0 fps.
# Processing 'Assault014_x264' in category 'Assault' at 30.0 fps.
# Processing 'Assault015_x264' in category 'Assault' at 30.0 fps.
# Processing 'Assault016_x264' in category 'Assault' at 30.0 fps.
# Processing 'Assault017_x264' in category 'Assault' at 30.0 fps.
# Processing 'Assault018_x264' in category 'Assault' at 30.0 fps.
# Processing 'Assault019_x264' in category 'Assault' at 30.0 fps.
# Processing 'Assault020_x264' in category 'Assault' at 30.0 fps.
# Processing 'Assault022_x264' in category 'Assault' at 30.0 fps.
# Processing 'Assault023_x264' in category 'Assault' at 30.0 fps.
# Processing 'Assault024_x264' in category 'Assault' at 30.0 fps.
# Processing 'Assault025_x264' in category 'Assault' at 30.0 fps.
# Processing 'Assault026_x264' in category 'Assault' at 30.0 fps.
# Processing 'Burglary001_x264' in category 'Burglary' at 30.0 fps.
# Processing 'Burglary002_x264' in category 'Burglary' at 30.0 fps.
# Processing 'Burglary003_x264' in category 'Burglary' at 30.0 fps.
# Processing 'Burglary004_x264' in category 'Burglary' at 30.0 fps.
# Processing 'Burglary005_x264' in category 'Burglary' at 30.0 fps.
# Processing 'Burglary006_x264' in category 'Burglary' at 30.0 fps.
# Processing 'Burglary007_x264' in category 'Burglary' at 30.0 fps.
# Processing 'Burglary008_x264' in category 'Burglary' at 30.0 fps.
# Processing 'Burglary009_x264' in category 'Burglary' at 30.0 fps.
# Processing 'Burglary010_x264' in category 'Burglary' at 30.0 fps.
# Processing 'Burglary011_x264' in category 'Burglary' at 30.0 fps.
# Processing 'Burglary012_x264' in category 'Burglary' at 30.0 fps.
# Processing 'Burglary013_x264' in category 'Burglary' at 30.0 fps.
# Processing 'Burglary014_x264' in category 'Burglary' at 30.0 fps.
# Processing 'Burglary015_x264' in category 'Burglary' at 30.0 fps.
# Processing 'Burglary016_x264' in category 'Burglary' at 30.0 fps.
# Processing 'Burglary017_x264' in category 'Burglary' at 30.0 fps.
# Processing 'Burglary018_x264' in category 'Burglary' at 30.0 fps.
# Processing 'Burglary019_x264' in category 'Burglary' at 30.0 fps.
# Processing 'Burglary020_x264' in category 'Burglary' at 30.0 fps.
# Processing 'Burglary021_x264' in category 'Burglary' at 30.0 fps.
# Processing 'Burglary022_x264' in category 'Burglary' at 30.0 fps.
# Processing 'Burglary023_x264' in category 'Burglary' at 30.0 fps.
# Processing 'Burglary024_x264' in category 'Burglary' at 30.0 fps.
# Processing 'Burglary025_x264' in category 'Burglary' at 30.0 fps.
# Processing 'Burglary026_x264' in category 'Burglary' at 30.0 fps.
# Processing 'Burglary027_x264' in category 'Burglary' at 30.0 fps.
# Processing 'Burglary028_x264' in category 'Burglary' at 30.0 fps.
# Processing 'Burglary029_x264' in category 'Burglary' at 30.0 fps.
# Processing 'Burglary030_x264' in category 'Burglary' at 30.0 fps.
# Processing 'Burglary031_x264' in category 'Burglary' at 30.0 fps.
# Processing 'Burglary032_x264' in category 'Burglary' at 30.0 fps.
# Processing 'Burglary033_x264' in category 'Burglary' at 30.0 fps.
# Processing 'Burglary034_x264' in category 'Burglary' at 30.0 fps.
# Processing 'Burglary035_x264' in category 'Burglary' at 30.0 fps.
# Processing 'Burglary036_x264' in category 'Burglary' at 30.0 fps.
# Processing 'Burglary037_x264' in category 'Burglary' at 30.0 fps.
# Processing 'Burglary038_x264' in category 'Burglary' at 30.0 fps.
# Processing 'Burglary039_x264' in category 'Burglary' at 30.0 fps.
# Processing 'Burglary040_x264' in category 'Burglary' at 30.0 fps.
# Processing 'Burglary041_x264' in category 'Burglary' at 30.0 fps.
# Processing 'Burglary042_x264' in category 'Burglary' at 30.0 fps.
# Processing 'Burglary043_x264' in category 'Burglary' at 30.0 fps.
# Processing 'Burglary044_x264' in category 'Burglary' at 30.0 fps.
# Processing 'Burglary045_x264' in category 'Burglary' at 30.0 fps.
# Processing 'Burglary046_x264' in category 'Burglary' at 30.0 fps.
# Processing 'Burglary047_x264' in category 'Burglary' at 30.0 fps.
# Processing 'Burglary048_x264' in category 'Burglary' at 30.0 fps.
# Processing 'Burglary049_x264' in category 'Burglary' at 30.0 fps.
# Processing 'Burglary050_x264' in category 'Burglary' at 30.0 fps.
# Processing 'Burglary051_x264' in category 'Burglary' at 30.0 fps.
# Processing 'Burglary052_x264' in category 'Burglary' at 30.0 fps.
# Processing 'Burglary053_x264' in category 'Burglary' at 30.0 fps.
# Processing 'Burglary054_x264' in category 'Burglary' at 30.0 fps.
# Processing 'Burglary055_x264' in category 'Burglary' at 30.0 fps.
# Processing 'Burglary056_x264' in category 'Burglary' at 30.0 fps.
# Processing 'Burglary057_x264' in category 'Burglary' at 30.0 fps.
# Processing 'Burglary058_x264' in category 'Burglary' at 30.0 fps.
# Processing 'Burglary059_x264' in category 'Burglary' at 30.0 fps.
# Processing 'Burglary060_x264' in category 'Burglary' at 30.0 fps.
# Processing 'Burglary061_x264' in category 'Burglary' at 30.0 fps.
# Processing 'Burglary062_x264' in category 'Burglary' at 30.0 fps.
# Processing 'Burglary063_x264' in category 'Burglary' at 30.0 fps.
# Processing 'Burglary064_x264' in category 'Burglary' at 30.0 fps.
# Processing 'Explosion001_x264' in category 'Explosion' at 30.0 fps.
# Processing 'Explosion002_x264' in category 'Explosion' at 30.0 fps.
# Processing 'Explosion003_x264' in category 'Explosion' at 30.0 fps.
# Processing 'Explosion004_x264' in category 'Explosion' at 30.0 fps.
# Processing 'Explosion005_x264' in category 'Explosion' at 30.0 fps.
# Processing 'Explosion006_x264' in category 'Explosion' at 30.0 fps.
# Processing 'Explosion046_x264' in category 'Explosion' at 30.0 fps.
# Processing 'Fighting002_x264' in category 'Fighting' at 30.0 fps.
# Processing 'Fighting003_x264' in category 'Fighting' at 30.0 fps.
# Processing 'Fighting004_x264' in category 'Fighting' at 30.0 fps.
# Processing 'Fighting005_x264' in category 'Fighting' at 30.0 fps.
# Processing 'Fighting006_x264' in category 'Fighting' at 30.0 fps.
# Processing 'Fighting007_x264' in category 'Fighting' at 30.0 fps.
# Processing 'Fighting008_x264' in category 'Fighting' at 30.0 fps.
# Processing 'Fighting009_x264' in category 'Fighting' at 30.0 fps.
# Processing 'Fighting010_x264' in category 'Fighting' at 30.0 fps.
# Processing 'Fighting011_x264' in category 'Fighting' at 30.0 fps.
# Processing 'Fighting012_x264' in category 'Fighting' at 30.0 fps.
# Processing 'Fighting013_x264' in category 'Fighting' at 30.0 fps.
# Processing 'Fighting014_x264' in category 'Fighting' at 30.0 fps.
# Processing 'Fighting015_x264' in category 'Fighting' at 30.0 fps.
# Processing 'Fighting016_x264' in category 'Fighting' at 30.0 fps.
# Processing 'Fighting017_x264' in category 'Fighting' at 30.0 fps.
# Processing 'Fighting018_x264' in category 'Fighting' at 30.0 fps.
# Processing 'Fighting019_x264' in category 'Fighting' at 30.0 fps.
# Processing 'Fighting020_x264' in category 'Fighting' at 30.0 fps.
# Processing 'Fighting021_x264' in category 'Fighting' at 30.0 fps.
# Processing 'Fighting022_x264' in category 'Fighting' at 30.0 fps.
# Processing 'Fighting023_x264' in category 'Fighting' at 30.0 fps.
# Processing 'Fighting024_x264' in category 'Fighting' at 30.0 fps.
# Processing 'Fighting025_x264' in category 'Fighting' at 30.0 fps.
# Processing 'Fighting026_x264' in category 'Fighting' at 30.0 fps.
# Processing 'Fighting027_x264' in category 'Fighting' at 30.0 fps.
# Processing 'Fighting028_x264' in category 'Fighting' at 30.0 fps.
# Processing 'Fighting029_x264' in category 'Fighting' at 30.0 fps.
# Processing 'Fighting030_x264' in category 'Fighting' at 30.0 fps.
# Processing 'Fighting031_x264' in category 'Fighting' at 30.0 fps.
# Processing 'Fighting032_x264' in category 'Fighting' at 30.0 fps.
# Processing 'Fighting033_x264' in category 'Fighting' at 30.0 fps.
# Processing 'Fighting034_x264' in category 'Fighting' at 30.0 fps.
# Processing 'Fighting035_x264' in category 'Fighting' at 30.0 fps.
# Processing 'Fighting036_x264' in category 'Fighting' at 30.0 fps.
# Processing 'Fighting037_x264' in category 'Fighting' at 30.0 fps.
# Processing 'Fighting038_x264' in category 'Fighting' at 30.0 fps.
# Processing 'RoadAccidents001_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents002_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents003_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents004_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents005_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents006_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents007_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents008_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents009_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents010_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents011_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents012_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents013_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents014_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents015_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents016_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents017_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents018_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents019_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents020_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents021_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents022_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents023_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents024_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents025_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents026_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents027_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents028_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents029_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents030_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents031_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents032_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents033_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents034_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents035_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents036_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents037_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents038_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents039_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents040_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents041_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents042_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents043_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents044_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents046_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents047_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents048_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents049_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents050_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents051_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents052_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents053_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents054_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents055_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents056_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents057_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents058_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents059_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents060_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents061_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents062_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents064_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents065_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents066_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents067_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents068_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents069_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents070_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents071_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents072_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents073_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents074_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents075_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents076_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents077_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents078_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents079_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents080_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents081_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents082_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents083_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents084_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents085_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents086_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents087_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents088_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents089_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents090_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents091_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents092_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents093_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents094_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents095_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents096_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents097_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents098_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents099_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents100_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents101_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents102_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents103_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents104_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents105_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents106_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents107_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'RoadAccidents108_x264' in category 'RoadAccidents' at 30.0 fps.
# Processing 'Robbery001_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery002_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery003_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery004_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery005_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery006_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery007_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery008_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery009_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery010_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery011_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery012_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery013_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery014_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery015_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery016_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery017_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery018_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery019_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery020_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery021_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery022_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery023_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery024_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery025_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery026_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery027_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery028_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery029_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery030_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery031_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery032_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery033_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery034_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery035_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery036_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery037_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery038_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery039_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery040_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery041_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery042_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery043_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery044_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery045_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery046_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery047_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery048_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery049_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery050_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery051_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery052_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery053_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery054_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery055_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery056_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery057_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery058_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery059_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery060_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery061_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery062_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery063_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery064_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery065_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery066_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery067_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery068_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery069_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery070_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery071_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery072_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery073_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery074_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery075_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery076_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery077_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery078_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery079_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery080_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery081_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery082_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery083_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Robbery084_x264' in category 'Robbery' at 30.0 fps.
# Processing 'Shooting001_x264' in category 'Shooting' at 30.0 fps.
# Processing 'Shooting002_x264' in category 'Shooting' at 30.0 fps.
# Processing 'Shooting003_x264' in category 'Shooting' at 30.0 fps.
# Processing 'Shooting004_x264' in category 'Shooting' at 30.0 fps.
# Processing 'Shooting005_x264' in category 'Shooting' at 30.0 fps.
# Processing 'Shooting006_x264' in category 'Shooting' at 30.0 fps.
# Processing 'Shooting007_x264' in category 'Shooting' at 30.0 fps.
# Processing 'Shooting008_x264' in category 'Shooting' at 30.0 fps.
# Processing 'Shooting009_x264' in category 'Shooting' at 30.0 fps.
# Processing 'Shooting010_x264' in category 'Shooting' at 30.0 fps.
# Processing 'Shooting011_x264' in category 'Shooting' at 30.0 fps.
# Processing 'Shooting012_x264' in category 'Shooting' at 30.0 fps.
# Processing 'Shooting013_x264' in category 'Shooting' at 30.0 fps.
# Processing 'Shooting014_x264' in category 'Shooting' at 30.0 fps.
# Processing 'Shooting015_x264' in category 'Shooting' at 30.0 fps.
# Processing 'Shooting017_x264' in category 'Shooting' at 30.0 fps.
# Processing 'Shooting018_x264' in category 'Shooting' at 30.0 fps.
# Processing 'Shooting019_x264' in category 'Shooting' at 30.0 fps.
# Processing 'Shooting020_x264' in category 'Shooting' at 30.0 fps.
# Processing 'Shooting021_x264' in category 'Shooting' at 30.0 fps.
# Processing 'Shooting022_x264' in category 'Shooting' at 30.0 fps.
# Processing 'Shooting023_x264' in category 'Shooting' at 30.0 fps.
# Processing 'Shooting024_x264' in category 'Shooting' at 30.0 fps.
# Processing 'Shooting025_x264' in category 'Shooting' at 30.0 fps.
# Processing 'Shooting026_x264' in category 'Shooting' at 30.0 fps.
# Processing 'Shooting027_x264' in category 'Shooting' at 30.0 fps.
# Processing 'Shooting028_x264' in category 'Shooting' at 30.0 fps.
# Processing 'Shooting029_x264' in category 'Shooting' at 30.0 fps.
# Processing 'Shooting030_x264' in category 'Shooting' at 30.0 fps.
# Processing 'Shooting031_x264' in category 'Shooting' at 30.0 fps.
# Processing 'Shooting032_x264' in category 'Shooting' at 30.0 fps.
# Processing 'Shoplifting001_x264' in category 'Shoplifting' at 30.0 fps.
# Processing 'Shoplifting003_x264' in category 'Shoplifting' at 30.0 fps.
# Processing 'Shoplifting004_x264' in category 'Shoplifting' at 30.0 fps.
# Processing 'Shoplifting005_x264' in category 'Shoplifting' at 30.0 fps.
# Processing 'Shoplifting006_x264' in category 'Shoplifting' at 30.0 fps.
# Processing 'Shoplifting007_x264' in category 'Shoplifting' at 30.0 fps.
# Processing 'Shoplifting008_x264' in category 'Shoplifting' at 30.0 fps.
# Processing 'Shoplifting009_x264' in category 'Shoplifting' at 30.0 fps.
# Processing 'Shoplifting010_x264' in category 'Shoplifting' at 30.0 fps.
# Processing 'Shoplifting012_x264' in category 'Shoplifting' at 30.0 fps.
# Processing 'Shoplifting013_x264' in category 'Shoplifting' at 30.0 fps.
# Processing 'Shoplifting014_x264' in category 'Shoplifting' at 30.0 fps.
# Processing 'Shoplifting015_x264' in category 'Shoplifting' at 30.0 fps.
# Processing 'Shoplifting016_x264' in category 'Shoplifting' at 30.0 fps.
# Processing 'Shoplifting017_x264' in category 'Shoplifting' at 30.0 fps.
# Processing 'Shoplifting018_x264' in category 'Shoplifting' at 30.0 fps.
# Processing 'Shoplifting019_x264' in category 'Shoplifting' at 30.0 fps.
# Processing 'Shoplifting020_x264' in category 'Shoplifting' at 30.0 fps.
# Processing 'Shoplifting021_x264' in category 'Shoplifting' at 30.0 fps.
# Processing 'Shoplifting022_x264' in category 'Shoplifting' at 30.0 fps.
# Processing 'Shoplifting024_x264' in category 'Shoplifting' at 30.0 fps.
# Processing 'Shoplifting025_x264' in category 'Shoplifting' at 30.0 fps.
# Processing 'Shoplifting026_x264' in category 'Shoplifting' at 30.0 fps.
# Processing 'Shoplifting027_x264' in category 'Shoplifting' at 30.0 fps.
# Processing 'Shoplifting028_x264' in category 'Shoplifting' at 30.0 fps.
# Processing 'Shoplifting029_x264' in category 'Shoplifting' at 30.0 fps.
# Processing 'Shoplifting030_x264' in category 'Shoplifting' at 30.0 fps.
# Processing 'Shoplifting031_x264' in category 'Shoplifting' at 30.0 fps.
# Processing 'Shoplifting032_x264' in category 'Shoplifting' at 30.0 fps.
# Processing 'Shoplifting033_x264' in category 'Shoplifting' at 30.0 fps.
# Processing 'Stealing002_x264' in category 'Stealing' at 30.0 fps.
# Processing 'Stealing003_x264' in category 'Stealing' at 30.0 fps.
# Processing 'Stealing004_x264' in category 'Stealing' at 30.0 fps.
# Processing 'Stealing006_x264' in category 'Stealing' at 30.0 fps.
# Processing 'Stealing007_x264' in category 'Stealing' at 30.0 fps.
# Processing 'Stealing008_x264' in category 'Stealing' at 30.0 fps.
# Processing 'Stealing009_x264' in category 'Stealing' at 30.0 fps.
# Processing 'Stealing010_x264' in category 'Stealing' at 30.0 fps.
# Processing 'Stealing011_x264' in category 'Stealing' at 30.0 fps.
# Processing 'Stealing012_x264' in category 'Stealing' at 30.0 fps.
# Processing 'Stealing013_x264' in category 'Stealing' at 30.0 fps.
# Processing 'Stealing014_x264' in category 'Stealing' at 30.0 fps.
# Processing 'Stealing015_x264' in category 'Stealing' at 30.0 fps.
# Processing 'Stealing016_x264' in category 'Stealing' at 30.0 fps.
# Processing 'Stealing017_x264' in category 'Stealing' at 30.0 fps.
# Processing 'Stealing018_x264' in category 'Stealing' at 30.0 fps.
# Processing 'Stealing019_x264' in category 'Stealing' at 30.0 fps.
# Processing 'Stealing020_x264' in category 'Stealing' at 30.0 fps.
# Processing 'Stealing021_x264' in category 'Stealing' at 30.0 fps.
# Processing 'Stealing022_x264' in category 'Stealing' at 30.0 fps.
# Processing 'Stealing023_x264' in category 'Stealing' at 30.0 fps.
# Processing 'Stealing024_x264' in category 'Stealing' at 30.0 fps.
# Processing 'Stealing025_x264' in category 'Stealing' at 30.0 fps.
# Processing 'Stealing026_x264' in category 'Stealing' at 30.0 fps.
# Processing 'Stealing027_x264' in category 'Stealing' at 30.0 fps.
# Processing 'Stealing028_x264' in category 'Stealing' at 30.0 fps.
# Processing 'Stealing029_x264' in category 'Stealing' at 30.0 fps.
# Processing 'Stealing030_x264' in category 'Stealing' at 30.0 fps.
# Processing 'Stealing031_x264' in category 'Stealing' at 30.0 fps.
# Processing 'Stealing032_x264' in category 'Stealing' at 30.0 fps.
# Processing 'Stealing035_x264' in category 'Stealing' at 30.0 fps.
# Processing 'Stealing036_x264' in category 'Stealing' at 30.0 fps.
# Processing 'Stealing037_x264' in category 'Stealing' at 30.0 fps.
# Processing 'Stealing042_x264' in category 'Stealing' at 30.0 fps.
# Processing 'Stealing043_x264' in category 'Stealing' at 30.0 fps.
# Processing 'Stealing044_x264' in category 'Stealing' at 30.0 fps.
# Processing 'Stealing045_x264' in category 'Stealing' at 30.0 fps.
# Processing 'Stealing046_x264' in category 'Stealing' at 30.0 fps.
# Processing 'Stealing047_x264' in category 'Stealing' at 30.0 fps.
# Processing 'Stealing048_x264' in category 'Stealing' at 30.0 fps.
# Processing 'Stealing049_x264' in category 'Stealing' at 30.0 fps.
# Processing 'Stealing050_x264' in category 'Stealing' at 30.0 fps.
# Processing 'Stealing051_x264' in category 'Stealing' at 30.0 fps.
# Processing 'Stealing052_x264' in category 'Stealing' at 30.0 fps.
# Processing 'Stealing053_x264' in category 'Stealing' at 30.0 fps.
# Processing 'Stealing054_x264' in category 'Stealing' at 30.0 fps.
# Processing 'Stealing055_x264' in category 'Stealing' at 30.0 fps.
# Processing 'Stealing057_x264' in category 'Stealing' at 30.0 fps.
# Processing 'Stealing058_x264' in category 'Stealing' at 30.0 fps.
# Processing 'Stealing059_x264' in category 'Stealing' at 30.0 fps.
# Processing 'Stealing060_x264' in category 'Stealing' at 30.0 fps.
# Processing 'Stealing061_x264' in category 'Stealing' at 30.0 fps.
# Processing 'Stealing062_x264' in category 'Stealing' at 30.0 fps.
# Processing 'Stealing063_x264' in category 'Stealing' at 30.0 fps.
# Processing 'Stealing065_x264' in category 'Stealing' at 30.0 fps.
# Processing 'Stealing066_x264' in category 'Stealing' at 30.0 fps.
# Processing 'Stealing067_x264' in category 'Stealing' at 30.0 fps.
# Processing 'Stealing068_x264' in category 'Stealing' at 30.0 fps.
# Processing 'Stealing069_x264' in category 'Stealing' at 30.0 fps.
# Processing 'Stealing070_x264' in category 'Stealing' at 30.0 fps.
# Processing 'Stealing071_x264' in category 'Stealing' at 30.0 fps.
# Processing 'Stealing072_x264' in category 'Stealing' at 30.0 fps.
# Processing 'Stealing073_x264' in category 'Stealing' at 30.0 fps.
# Processing 'Stealing074_x264' in category 'Stealing' at 30.0 fps.
# Processing 'Stealing075_x264' in category 'Stealing' at 30.0 fps.
# Processing 'Stealing077_x264' in category 'Stealing' at 30.0 fps.
# Processing 'Vandalism001_x264' in category 'Vandalism' at 30.0 fps.
# Processing 'Vandalism002_x264' in category 'Vandalism' at 30.0 fps.
# Processing 'Vandalism003_x264' in category 'Vandalism' at 30.0 fps.
# Processing 'Vandalism004_x264' in category 'Vandalism' at 30.0 fps.
# Processing 'Vandalism005_x264' in category 'Vandalism' at 30.0 fps.
# Processing 'Vandalism006_x264' in category 'Vandalism' at 30.0 fps.
# Processing 'Vandalism007_x264' in category 'Vandalism' at 30.0 fps.
# Processing 'Vandalism008_x264' in category 'Vandalism' at 30.0 fps.
# Processing 'Vandalism009_x264' in category 'Vandalism' at 30.0 fps.
# Processing 'Vandalism010_x264' in category 'Vandalism' at 30.0 fps.
# Processing 'Vandalism011_x264' in category 'Vandalism' at 30.0 fps.
# Processing 'Vandalism012_x264' in category 'Vandalism' at 30.0 fps.
# Processing 'Vandalism013_x264' in category 'Vandalism' at 30.0 fps.
# Processing 'Vandalism014_x264' in category 'Vandalism' at 30.0 fps.
# Processing 'Vandalism015_x264' in category 'Vandalism' at 30.0 fps.
# Processing 'Vandalism016_x264' in category 'Vandalism' at 30.0 fps.
# Processing 'Vandalism017_x264' in category 'Vandalism' at 30.0 fps.
# Processing 'Vandalism018_x264' in category 'Vandalism' at 30.0 fps.
# Processing 'Vandalism019_x264' in category 'Vandalism' at 30.0 fps.
# Processing 'Vandalism020_x264' in category 'Vandalism' at 30.0 fps.
# Processing 'Vandalism021_x264' in category 'Vandalism' at 30.0 fps.
# Processing 'Vandalism022_x264' in category 'Vandalism' at 30.0 fps.
# Processing 'Vandalism023_x264' in category 'Vandalism' at 30.0 fps.
# Processing 'Vandalism024_x264' in category 'Vandalism' at 30.0 fps.
# Processing 'Vandalism025_x264' in category 'Vandalism' at 30.0 fps.
# Processing 'Vandalism026_x264' in category 'Vandalism' at 30.0 fps.
# Processing 'Vandalism027_x264' in category 'Vandalism' at 30.0 fps.
# Processing 'Vandalism028_x264' in category 'Vandalism' at 30.0 fps.
# Processing 'Vandalism029_x264' in category 'Vandalism' at 30.0 fps.
# Processing 'Vandalism030_x264' in category 'Vandalism' at 30.0 fps.
# Processing 'Normal_Videos_003_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_006_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_010_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_014_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_015_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_018_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_019_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_024_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_025_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_027_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_033_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_034_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_041_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_042_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_048_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_050_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_196_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_051_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_056_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_059_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_063_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_067_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_070_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_100_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_129_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_150_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_168_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_175_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_182_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_189_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_203_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_210_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_217_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_224_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_246_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_247_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_248_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_251_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_289_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_310_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_312_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_317_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_345_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_352_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_360_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_365_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_401_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_439_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_452_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_453_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_478_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_576_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_597_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_603_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_606_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_621_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_634_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_641_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_656_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_686_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_696_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_702_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_704_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_710_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_717_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_722_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_725_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_745_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_758_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_778_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_780_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_781_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_782_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_783_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_798_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_801_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_828_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_831_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_866_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_867_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_868_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_869_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_870_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_871_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_872_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_873_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_874_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_875_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_877_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_878_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_879_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_880_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_881_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_882_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_883_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_884_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_885_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_886_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_887_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_889_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_888_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_890_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_891_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_892_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_893_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_894_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_895_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_899_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_896_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_897_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_898_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_900_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_901_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_902_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_903_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_904_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_905_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_906_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_907_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_908_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_909_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_910_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_911_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_912_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_913_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_914_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_915_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos_923_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos001_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos002_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos004_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos005_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos007_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos008_x264' in category 'Normal' at 30.0 fps.
# ...
# Processing 'Normal_Videos277_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos278_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos279_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos280_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos281_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos282_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos283_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos284_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos285_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos286_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos287_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos288_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos290_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos291_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos292_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos293_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos294_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos295_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos296_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos297_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos298_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos299_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos300_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos301_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos302_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos303_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos305_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos306_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos307_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos308_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos309_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos311_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos313_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos314_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos315_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos316_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos318_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos319_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos320_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos321_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos322_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos323_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos324_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos325_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos326_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos327_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos328_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos330_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos332_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos333_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos334_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos335_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos336_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos337_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos338_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos339_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos340_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos341_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos342_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos343_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos344_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos346_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos347_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos348_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos349_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos350_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos351_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos353_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos354_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos355_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos356_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos357_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos358_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos359_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos361_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos362_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos363_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos364_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos366_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos367_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos368_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos369_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos370_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos371_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos372_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos373_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos374_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos375_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos376_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos377_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos378_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos379_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos380_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos381_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos382_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos383_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos384_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos385_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos386_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos387_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos388_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos389_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos390_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos391_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos392_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos393_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos394_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos395_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos396_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos397_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos398_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos399_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos400_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos402_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos403_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos404_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos405_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos406_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos407_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos408_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos409_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos410_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos411_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos412_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos413_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos414_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos415_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos416_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos418_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos419_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos420_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos421_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos422_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos423_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos424_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos425_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos426_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos427_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos430_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos432_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos433_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos434_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos436_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos438_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos440_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos441_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos442_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos443_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos444_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos447_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos448_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos449_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos450_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos451_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos454_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos455_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos456_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos457_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos458_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos459_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos460_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos461_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos462_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos463_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos464_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos465_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos466_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos467_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos469_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos470_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos471_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos472_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos473_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos474_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos475_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos476_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos477_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos479_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos480_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos481_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos482_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos483_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos484_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos485_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos486_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos487_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos488_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos489_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos490_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos491_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos492_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos493_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos494_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos495_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos496_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos497_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos498_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos499_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos500_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos501_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos502_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos503_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos504_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos505_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos506_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos508_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos509_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos510_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos511_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos512_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos513_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos514_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos515_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos516_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos517_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos518_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos519_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos520_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos521_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos522_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos523_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos524_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos525_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos526_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos527_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos528_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos529_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos530_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos531_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos532_x264' in category 'Normal' at 30.0 fps.
# Processing 'Normal_Videos533_x264' in category 'Normal' at 30.0 fps.
# Data saved to train_image_captions.csv

# %% [markdown]
# ## Save output Data in a zip file

# %%
import shutil

# Define the output directory
output_dir = "/kaggle/working/test_output_frames"

# Define the name of the zip file
zip_filename = "test_ucf_output.zip"

# Create a zip file of the output directory
shutil.make_archive(base_name= zip_filename.replace('.zip', ''), format='zip', root_dir=output_dir)

print(f"Zipped the output directory to {zip_filename}")
# Out:
# Zipped the output directory to test_ucf_output.zip

# %% [markdown]
# ## Get Download Link for the zip file to download it in Google Drive

# %%
from IPython.display import FileLink
FileLink(r'train_ucf_output.zip')
# Out:
# /kaggle/working/train_ucf_output.zip

# %%
from IPython.display import FileLink
FileLink(r'test_ucf_output.zip')
# Out:
# /kaggle/working/test_ucf_output.zip

# %%
from IPython.display import FileLink
FileLink(r'Val_ucf_output.zip')
# Out:
# /kaggle/working/Val_ucf_output.zip

# %%
import os
import json
import random
import shutil
from collections import defaultdict

# === Paths ===
VIDEO_DIR = "/kaggle/input/ucaucf-crime-annotation-dataset/UCF_Crimes/UCF_Crimes/Videos"
ANNOTATION_JSON_PATH = "/kaggle/input/ucaucf-crime-annotation-dataset/UCFCrime_Train.json"  # Adjust if different
OUTPUT_DIR = "/kaggle/working/sampled_ucf_videos"
OUTPUT_JSON_PATH = os.path.join(OUTPUT_DIR, "sampled_annotations.json")

# === Load Annotations ===
with open(ANNOTATION_JSON_PATH, "r") as f:
    annotations = json.load(f)

# === Organize Videos by Category ===
category_videos = defaultdict(list)

for video_name in annotations:
    # Video name example: Abuse001_x264
    for category in os.listdir(VIDEO_DIR):
        if video_name.startswith(category):
            category_videos[category].append(video_name)
            break

# === Sample Videos and Copy to Output ===
sampled_data = {}
os.makedirs(OUTPUT_DIR, exist_ok=True)

for category, videos in category_videos.items():
    sampled = random.sample(videos, min(3, len(videos)))
    category_output_dir = os.path.join(OUTPUT_DIR, category)
    os.makedirs(category_output_dir, exist_ok=True)

    for video_name in sampled:
        video_file = video_name + ".mp4"  # Change if videos are .avi or another extension
        src_video_path = os.path.join(VIDEO_DIR, category, video_file)
        dst_video_path = os.path.join(category_output_dir, video_file)

        if os.path.exists(src_video_path):
            shutil.copy2(src_video_path, dst_video_path)
            sampled_data[video_name] = annotations[video_name]
        else:
            print(f"Warning: Video file not found: {src_video_path}")

# === Save Sampled Annotations ===
with open(OUTPUT_JSON_PATH, "w") as out_json:
    json.dump(sampled_data, out_json, indent=4)
1
print(f"✅ Sampling complete! Videos saved in: {OUTPUT_DIR}")
print(f"✅ New JSON annotations file: {OUTPUT_JSON_PATH}")
# Out:
# ✅ Sampling complete! Videos saved in: /kaggle/working/sampled_ucf_videos
# ✅ New JSON annotations file: /kaggle/working/sampled_ucf_videos/sampled_annotations.json

# %%
import shutil

# Define the output directory
output_dir = "/kaggle/working/sampled_ucf_videos"

# Define the name of the zip file
zip_filename = "sampled_ucf_videos.zip"

# Create a zip file of the output directory
shutil.make_archive(base_name= zip_filename.replace('.zip', ''), format='zip', root_dir=output_dir)

print(f"Zipped the output directory to {zip_filename}")
# Out:
# Zipped the output directory to sampled_ucf_videos.zip

# %%
from IPython.display import FileLink
FileLink(r'sampled_ucf_videos.zip')
# Out:
# /kaggle/working/sampled_ucf_videos.zip
